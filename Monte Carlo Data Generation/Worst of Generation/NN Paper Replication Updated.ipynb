# %% [markdown]
# # Initial Analysis of Data

# %%
import pandas as pd
Train_Raw = pd.read_parquet("Test_New.parquet")
Test_Raw = pd.read_parquet("Train_New.parquet")

# %%
Train_Raw.describe()
# Out:
#                S0_0          S0_1          S0_2       sigma_0       sigma_1  \
# count  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06
# mean   1.868607e+02  1.868605e+02  1.868165e+02  5.000531e-01  5.001468e-01
# std    9.958846e+01  9.967165e+01  9.957335e+01  2.887234e-01  2.886410e-01
# min    1.172166e+01  1.339653e+01  1.352048e+01  1.947196e-07  1.227992e-08
# 25%    1.176948e+02  1.177294e+02  1.176408e+02  2.500339e-01  2.503857e-01
# 50%    1.649082e+02  1.648561e+02  1.648720e+02  5.001459e-01  5.001793e-01
# 75%    2.310593e+02  2.309599e+02  2.309787e+02  7.502468e-01  7.501256e-01
# max    2.253572e+03  2.463150e+03  2.094249e+03  9.999996e-01  9.999998e-01
#
#             sigma_2      corr_0_1      corr_0_2      corr_1_2          K  \
# count  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06  5000000.0
# mean   4.998487e-01  4.284284e-01  4.288081e-01  4.777857e-01      100.0
# std    2.885436e-01  3.195096e-01  3.193338e-01  2.860526e-01        0.0
# min    3.966500e-09 -9.418687e-01 -9.540399e-01 -8.868241e-01      100.0
# 25%    2.500368e-01  2.210713e-01  2.211613e-01  2.986871e-01      100.0
# 50%    4.998605e-01  4.709321e-01  4.714426e-01  5.194424e-01      100.0
# 75%    7.495205e-01  6.776692e-01  6.779694e-01  6.979728e-01      100.0
# max    9.999997e-01  9.997548e-01  9.996756e-01  9.988353e-01      100.0
#
#                   r             T         price      price_se
# count  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06
# mean   3.000000e-02  2.531572e+00  2.010996e+01  3.481879e-01
# std    1.040834e-16  2.234199e+00  2.234305e+01  3.512012e-01
# min    3.000000e-02  3.968254e-03  0.000000e+00  0.000000e+00
# 25%    3.000000e-02  4.801587e-01  4.954270e+00  1.150919e-01
# 50%    3.000000e-02  1.920635e+00  1.341620e+01  2.703210e-01
# 75%    3.000000e-02  4.321429e+00  2.734932e+01  4.783610e-01
# max    3.000000e-02  7.337302e+00  3.993845e+02  4.588407e+01

# %%
Test_Raw.describe()
# Out:
#              S0_0        S0_1        S0_2     sigma_0     sigma_1     sigma_2  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   190.773149  197.929971  185.781610    0.502094    0.477829    0.478386
# std    103.996466  104.932425  101.620806    0.288685    0.294581    0.284789
# min     37.900938   39.870267   46.220392    0.000443    0.000053    0.003218
# 25%    113.845412  122.832261  113.881466    0.250524    0.219081    0.232890
# 50%    167.129997  173.221989  159.344098    0.486663    0.455278    0.461412
# 75%    241.443021  242.159316  231.876414    0.738569    0.742559    0.708934
# max    720.335733  736.254223  724.589314    0.998905    0.999365    0.992626
#
#          corr_0_1    corr_0_2    corr_1_2      K             r           T  \
# count  500.000000  500.000000  500.000000  500.0  5.000000e+02  500.000000
# mean     0.431724    0.424943    0.483941  100.0  3.000000e-02    2.488754
# std      0.332259    0.326901    0.286255    0.0  6.945843e-18    2.225893
# min     -0.761601   -0.635732   -0.521501  100.0  3.000000e-02    0.003968
# 25%      0.240831    0.220531    0.295914  100.0  3.000000e-02    0.480159
# 50%      0.493037    0.473467    0.519788  100.0  3.000000e-02    1.750000
# 75%      0.673119    0.690726    0.707977  100.0  3.000000e-02    4.063492
# max      0.987799    0.956534    0.978635  100.0  3.000000e-02    7.337302
#
#             price    price_se
# count  500.000000  500.000000
# mean    20.645150    0.003431
# std     24.177453    0.003413
# min      0.000000    0.000000
# 25%      4.859753    0.001090
# 50%     12.899301    0.002650
# 75%     28.141907    0.004723
# max    225.596180    0.026980

# %%
Train_Raw.head()
# Out:
#          S0_0        S0_1        S0_2   sigma_0   sigma_1   sigma_2  corr_0_1  \
# 0  211.352480  153.859221  227.924505  0.156019  0.155995  0.058084  0.595795
# 1  112.300907  162.868414  196.949203  0.859940  0.680308  0.450499  0.040739
# 2  661.378774  299.462754  183.917878  0.921874  0.088493  0.195983  0.542316
# 3  143.670105  226.630908  104.774440  0.790176  0.605960  0.926301  0.323487
# 4  111.644447  108.117868  152.918218  0.201719  0.895764  0.475370  0.160354
#
#    corr_0_2  corr_1_2      K     r         T      price  price_se
# 0  0.267429  0.404955  100.0  0.03  2.285714  58.921882  0.336377
# 1  0.310864  0.304059  100.0  0.03  1.285714  11.802256  0.335143
# 2  0.920858  0.695307  100.0  0.03  6.349206  57.754328  0.929427
# 3  0.165483  0.568074  100.0  0.03  6.670635   5.038754  0.550302
# 4  0.201242  0.880389  100.0  0.03  4.063492   6.295657  0.210357

# %%
Test_Raw.head()
# Out:
#          S0_0        S0_1        S0_2   sigma_0   sigma_1   sigma_2  corr_0_1  \
# 0  211.352480  153.859221  227.924505  0.156019  0.155995  0.058084  0.595795
# 1  112.300907  162.868414  196.949203  0.859940  0.680308  0.450499  0.040739
# 2  661.378774  299.462754  183.917878  0.921874  0.088493  0.195983  0.542316
# 3  143.670105  226.630908  104.774440  0.790176  0.605960  0.926301  0.323487
# 4  111.644447  108.117868  152.918218  0.201719  0.895764  0.475370  0.160354
#
#    corr_0_2  corr_1_2      K     r         T      price  price_se
# 0  0.267429  0.404955  100.0  0.03  2.285714  59.114475  0.003422
# 1  0.310864  0.304059  100.0  0.03  1.285714  11.351699  0.003264
# 2  0.920858  0.695307  100.0  0.03  6.349206  58.343190  0.009409
# 3  0.165483  0.568074  100.0  0.03  6.670635   4.867073  0.005575
# 4  0.201242  0.880389  100.0  0.03  4.063492   6.194364  0.002086

# %% [markdown]
# # Initial Data Cleaning

# %%
import pandas as pd
from pathlib import Path

def clean_parquet(src_path, dst_path):
    """
    • Divides every S0_* and price by the row’s K
    • Renames the results to `S0_i/K` and `price/k`
    • Removes *_se, the raw S0_*, price, and K columns
    • Drops rows where price/k < 1e-6
    """
    df = pd.read_parquet(src_path)

    # 1) locate relevant columns
    s0_cols = [c for c in df.columns if c.lower().startswith("s0_")]
    se_cols = [c for c in df.columns if c.endswith("_se")]

    # 2) create scaled columns with the requested names
    for col in s0_cols:
        df[f"{col}/K"] = df[col] / df["K"]
    df["price/k"] = df["price"] / df["K"]

    # 3) filter out extremely small payoffs
    df = df[df["price/k"] >= 1e-6]

    # 4) drop the original, now-redundant columns
    df = df.drop(columns=s0_cols + ["price", "K"] + se_cols)

    # 5) save the cleaned file
    df.to_parquet(dst_path, index=False)
    print(f"✔ Saved cleaned file → {dst_path!s}")

# Apply to both datasets
clean_parquet("Train_New.parquet", "Train_Clean.parquet")
clean_parquet("Test_New.parquet",  "Test_Clean.parquet")
# Out:
# ✔ Saved cleaned file → Train_Clean.parquet
# ✔ Saved cleaned file → Test_Clean.parquet

# %%
Train= pd.read_parquet("Train_Clean.parquet")
Test= pd.read_parquet("Test_Clean.parquet")

Train.describe()
# Out:
#           sigma_0     sigma_1     sigma_2    corr_0_1    corr_0_2    corr_1_2  \
# count  478.000000  478.000000  478.000000  478.000000  478.000000  478.000000
# mean     0.505903    0.479970    0.484368    0.435886    0.427642    0.485581
# std      0.286994    0.293250    0.283502    0.329516    0.326238    0.286732
# min      0.000443    0.000053    0.003218   -0.761601   -0.635732   -0.521501
# 25%      0.254064    0.231192    0.242139    0.246180    0.210241    0.294058
# 50%      0.492822    0.460761    0.478308    0.494805    0.473878    0.520421
# 75%      0.740394    0.741365    0.712430    0.672962    0.691685    0.714347
# max      0.998905    0.999365    0.992626    0.987799    0.956534    0.978635
#
#                   r           T      S0_0/K      S0_1/K      S0_2/K  \
# count  4.780000e+02  478.000000  478.000000  478.000000  478.000000
# mean   3.000000e-02    2.576368    1.917724    1.980071    1.866943
# std    6.946164e-18    2.219704    1.038006    1.002276    1.019306
# min    3.000000e-02    0.003968    0.379009    0.398703    0.462204
# 25%    3.000000e-02    0.571429    1.151004    1.258015    1.142625
# 50%    3.000000e-02    1.920635    1.673263    1.769532    1.594194
# 75%    3.000000e-02    4.321429    2.413804    2.423220    2.318785
# max    3.000000e-02    7.337302    7.203357    6.310235    7.245893
#
#           price/k
# count  478.000000
# mean     0.215953
# std      0.243094
# min      0.000001
# 25%      0.057591
# 50%      0.138740
# 75%      0.290018
# max      2.255962

# %%
Test.describe()
# Out:
#             sigma_0       sigma_1       sigma_2      corr_0_1      corr_0_2  \
# count  4.783475e+06  4.783475e+06  4.783475e+06  4.783475e+06  4.783475e+06
# mean   5.043232e-01  5.043864e-01  5.040256e-01  4.285898e-01  4.290077e-01
# std    2.872319e-01  2.871350e-01  2.870717e-01  3.193576e-01  3.191790e-01
# min    1.947196e-07  1.755061e-07  3.966500e-09 -9.418687e-01 -9.540399e-01
# 25%    2.567135e-01  2.569976e-01  2.566013e-01  2.213243e-01  2.213841e-01
# 50%    5.053930e-01  5.054476e-01  5.050564e-01  4.710390e-01  4.715801e-01
# 75%    7.531562e-01  7.529624e-01  7.523301e-01  6.777370e-01  6.780375e-01
# max    9.999996e-01  9.999998e-01  9.999997e-01  9.997548e-01  9.996756e-01
#
#            corr_1_2             r             T        S0_0/K        S0_1/K  \
# count  4.783475e+06  4.783475e+06  4.783475e+06  4.783475e+06  4.783475e+06
# mean   4.779840e-01  3.000000e-02  2.612811e+00  1.886339e+00  1.886239e+00
# std    2.859013e-01  1.561251e-16  2.232102e+00  9.922917e-01  9.931811e-01
# min   -8.868241e-01  3.000000e-02  3.968254e-03  1.476079e-01  1.359094e-01
# 25%    2.989427e-01  3.000000e-02  5.714286e-01  1.196847e+00  1.197053e+00
# 50%    5.196222e-01  3.000000e-02  2.099206e+00  1.664278e+00  1.663331e+00
# 75%    6.980627e-01  3.000000e-02  4.321429e+00  2.323761e+00  2.322836e+00
# max    9.988353e-01  3.000000e-02  7.337302e+00  2.253572e+01  2.463150e+01
#
#              S0_2/K       price/k
# count  4.783475e+06  4.783475e+06
# mean   1.885640e+00  2.102024e-01
# std    9.918180e-01  2.242040e-01
# min    1.615864e-01  1.000117e-06
# 25%    1.196232e+00  5.943047e-02
# 50%    1.663616e+00  1.429890e-01
# 75%    2.323120e+00  2.826454e-01
# max    2.094249e+01  3.993845e+00

# %% [markdown]
# # Neural Network

# %%
# Cell 1 — imports & device setup
import os, math, random, time, pathlib, re
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

from torchmetrics import R2Score

# Use inline plots
# %matplotlib inline

os.environ.setdefault("NCCL_P2P_LEVEL", "0")
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on:", DEVICE)

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# Cell 2 — load & split cleaned Parquet into train/val/test TensorDatasets

# 1) Read cleaned Parquet files
#    (assumes you have already run clean_parquet on Train.parquet and Test100M.parquet)
train_df = pd.read_parquet("Train_clean.parquet", engine="pyarrow")
test_df  = pd.read_parquet("Test_clean.parquet", engine="pyarrow")

# 2) Split train_df → 80% train, 20% validation
X_full = train_df.drop(columns=["price/k"]).values.astype(np.float32)
y_full = train_df["price/k"].values.astype(np.float32)
X_tr_np, X_val_np, y_tr_np, y_val_np = train_test_split(
    X_full, y_full, test_size=0.01, random_state=42
)

# 3) Build TensorDatasets
train_ds = TensorDataset(torch.from_numpy(X_tr_np), torch.from_numpy(y_tr_np))
val_ds   = TensorDataset(torch.from_numpy(X_val_np), torch.from_numpy(y_val_np))
test_ds  = TensorDataset(
    torch.from_numpy(test_df.drop(columns=["price/k"]).values.astype(np.float32)),
    torch.from_numpy(test_df["price/k"].values.astype(np.float32))
)

print(f"train {len(train_ds):,} rows")
print(f"valid {len(val_ds):,} rows")
print(f" test {len(test_ds):,} rows")
# Out:
# Running on: cuda
# train 473 rows
# valid 5 rows
#  test 4,783,475 rows

# %%
# Cell 3 — define the MLP (BasketNet) model

class BasketNet(nn.Module):
    def __init__(self, in_dim: int, width: int, layers: int):
        """
        in_dim = number of input features
        width  = nodes per hidden layer
        layers = number of hidden layers
        """
        super().__init__()
        blocks = [nn.Linear(in_dim, width), nn.ReLU()]
        for _ in range(layers - 1):
            blocks += [nn.Linear(width, width), nn.ReLU()]
        blocks.append(nn.Linear(width, 1))
        self.net = nn.Sequential(*blocks)

        # Xavier initialization
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        return self.net(x)


def run_experiment_updates_per_update(
    width: int = 300,
    layers: int = 4,
    batch_size: int = 50_000,
    n_updates: int = 100_000,     # total mini‐batch updates
    lr: float = 1e-3,
    optimizer_name: str = "Adam",
    seed: int = 42,
    save_model: bool = False,      # ← new flag
    log_every: int = 1             # record every `log_every` updates
):
    """
    Train for exactly n_updates mini‐batches, recording
    train/val MSE at each update, then evaluate on test set.

    Args:
      width, layers:    model architecture
      batch_size:       mini‐batch size
      n_updates:        total optimizer steps (updates)
      lr:               learning rate
      optimizer_name:   "Adam" | "SGD" | "LBFGS"
      seed:             random seed
      save_model:       if True, save final weights to disk
      log_every:        record/compute validation every log_every steps
    """
    # 5.1) Re‐seed for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    # 5.2) Build DataLoaders
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False, pin_memory=True)
    test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False, pin_memory=True)

    # 5.3) Instantiate the model
    in_dim = train_ds[0][0].shape[0]
    model = BasketNet(in_dim, width, layers).to(DEVICE)
    if DEVICE.type == "cuda" and torch.cuda.device_count() > 1:
        model = nn.DataParallel(model)

    # 5.4) Loss & optimizer
    criterion = nn.MSELoss()
    if optimizer_name == "Adam":
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif optimizer_name == "SGD":
        optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    elif optimizer_name == "LBFGS":
        optimizer = optim.LBFGS(model.parameters(), lr=lr, max_iter=20)
    else:
        raise ValueError(f"Unknown optimizer: {optimizer_name}")

    # 5.5) Create an infinite iterator over shuffled train_loader
    def infinite_train_iter(loader):
        while True:
            for batch in loader:
                yield batch

    inf_train = infinite_train_iter(train_loader)

    # 5.6) Storage for train/val losses
    train_losses   = []
    valid_losses   = []
    steps_recorded = []

    # decide how often to print (every 10% of total updates)
    print_every = max(1, n_updates // 10)

    # 5.7) Main loop: exactly n_updates optimizer steps
    model.train()
    for step in range(1, n_updates + 1):
        # ----- 1) one optimizer step -----
        Xb, yb = next(inf_train)
        Xb, yb = Xb.to(DEVICE), yb.to(DEVICE).unsqueeze(1)
        optimizer.zero_grad(set_to_none=True)
        out       = model(Xb)
        loss      = criterion(out, yb)
        loss.backward()
        optimizer.step()
        loss_train = loss.item()

        # ----- 2) record & validate every log_every steps -----
        if step == 1 or step == n_updates or (step % log_every == 0):
            # validation pass
            model.eval()
            tot_val, cnt_val = 0.0, 0
            with torch.no_grad():
                for Xv, yv in val_loader:
                    Xv, yv = Xv.to(DEVICE), yv.to(DEVICE).unsqueeze(1)
                    ov = model(Xv)
                    tot_val += criterion(ov, yv).item() * Xv.size(0)
                    cnt_val += Xv.size(0)
            val_mse = tot_val / cnt_val

            # stash losses
            steps_recorded.append(step)
            train_losses.append(loss_train)
            valid_losses.append(val_mse)

            model.train()

            # ----- 3) print only at the first, last, or each 10% milestone -----
            if step == 1 or step == n_updates or (step % print_every == 0):
                print(f"[upd {step}/{n_updates}] "
                      f"train MSE={loss_train:.3e}  val MSE={val_mse:.3e}")

    # ---- 4) plot on the down-sampled grid ----
    train_min = np.minimum.accumulate(train_losses)
    valid_min = np.minimum.accumulate(valid_losses)

    plt.figure(figsize=(7, 4))
    plt.plot(steps_recorded, np.log10(train_min), label="train (cum-min)")
    plt.plot(steps_recorded, np.log10(valid_min), label="valid (cum-min)")
    plt.xlabel("update step")
    plt.ylabel("log10 MSE")
    plt.title(f"{layers}×{width} • bs={batch_size} • {optimizer_name}")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # 5.9) Final test‐set evaluation
    model.eval()
    all_preds, all_truths = [], []
    with torch.no_grad():
        for Xb, yb in test_loader:
            pr = model(Xb.to(DEVICE)).cpu().squeeze()
            all_preds.append(pr)
            all_truths.append(yb)
    preds  = torch.cat(all_preds)
    truths = torch.cat(all_truths)
    test_mse = criterion(preds.unsqueeze(1), truths.unsqueeze(1)).item()
    test_r2  = R2Score()(preds, truths).cpu().item()
    print(f"\nTest results → MSE = {test_mse:.3e}   R² = {test_r2:.4f}")

    # 5.10) Optionally save model weights
    if save_model:
        tag = f"w{width}_L{layers}_bs{batch_size}_upd{n_updates}_" \
              f"{optimizer_name}_lr{lr:g}"
        torch.save(model.state_dict(), f"model_{tag}.pt")
        print(f"Saved model to model_{tag}.pt")

# %% [markdown]
# # Inital Testing Model (1 epoch)

# %% [markdown]
# ## 3x4

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=5000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
    )
# Out:
# [upd 1/1000] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 100/1000] train MSE=1.571e-03  val MSE=7.049e-03
# [upd 200/1000] train MSE=2.843e-04  val MSE=5.626e-03
# [upd 300/1000] train MSE=3.417e-04  val MSE=5.259e-03
# [upd 400/1000] train MSE=4.287e-05  val MSE=4.752e-03
# [upd 500/1000] train MSE=4.639e-05  val MSE=4.746e-03
# [upd 600/1000] train MSE=9.927e-06  val MSE=4.645e-03
# [upd 700/1000] train MSE=7.447e-05  val MSE=4.575e-03
# [upd 800/1000] train MSE=9.287e-06  val MSE=4.483e-03
# [upd 900/1000] train MSE=3.056e-04  val MSE=4.592e-03
# [upd 1000/1000] train MSE=2.950e-06  val MSE=4.409e-03
# Test results → MSE = 5.392e-03   R² = 0.8927

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=10000,
        n_updates=500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
    )
# Out:
# [upd 1/500] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 50/500] train MSE=7.083e-03  val MSE=4.290e-03
# [upd 100/500] train MSE=1.571e-03  val MSE=7.049e-03
# [upd 150/500] train MSE=7.377e-04  val MSE=5.947e-03
# [upd 200/500] train MSE=2.843e-04  val MSE=5.626e-03
# [upd 250/500] train MSE=3.020e-04  val MSE=5.389e-03
# [upd 300/500] train MSE=3.417e-04  val MSE=5.259e-03
# [upd 350/500] train MSE=7.936e-04  val MSE=4.818e-03
# [upd 400/500] train MSE=4.287e-05  val MSE=4.752e-03
# [upd 450/500] train MSE=2.200e-05  val MSE=4.776e-03
# [upd 500/500] train MSE=4.639e-05  val MSE=4.746e-03
# Test results → MSE = 5.574e-03   R² = 0.8891

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=20000,
        n_updates=250,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/250] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 25/250] train MSE=1.897e-02  val MSE=7.333e-03
# [upd 50/250] train MSE=7.083e-03  val MSE=4.290e-03
# [upd 75/250] train MSE=2.877e-03  val MSE=6.808e-03
# [upd 100/250] train MSE=1.571e-03  val MSE=7.049e-03
# [upd 125/250] train MSE=8.752e-04  val MSE=6.340e-03
# [upd 150/250] train MSE=7.377e-04  val MSE=5.947e-03
# [upd 175/250] train MSE=4.340e-04  val MSE=5.832e-03
# [upd 200/250] train MSE=2.843e-04  val MSE=5.626e-03
# [upd 225/250] train MSE=5.250e-04  val MSE=5.805e-03
# [upd 250/250] train MSE=3.020e-04  val MSE=5.389e-03
# Test results → MSE = 5.931e-03   R² = 0.8820

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=50000,
        n_updates=100,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/100] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 10/100] train MSE=4.921e-02  val MSE=2.949e-02
# [upd 20/100] train MSE=2.780e-02  val MSE=7.567e-03
# [upd 30/100] train MSE=1.669e-02  val MSE=3.901e-03
# [upd 40/100] train MSE=1.015e-02  val MSE=3.324e-03
# [upd 50/100] train MSE=7.083e-03  val MSE=4.290e-03
# [upd 60/100] train MSE=4.787e-03  val MSE=5.663e-03
# [upd 70/100] train MSE=3.396e-03  val MSE=6.290e-03
# [upd 80/100] train MSE=2.490e-03  val MSE=7.124e-03
# [upd 90/100] train MSE=1.867e-03  val MSE=7.131e-03
# [upd 100/100] train MSE=1.571e-03  val MSE=7.049e-03
# Test results → MSE = 6.787e-03   R² = 0.8650

# %% [markdown]
# ## 5x 2.5

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=5000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/1000] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 100/1000] train MSE=6.719e-04  val MSE=8.163e-03
# [upd 200/1000] train MSE=8.183e-04  val MSE=6.930e-03
# [upd 300/1000] train MSE=4.771e-04  val MSE=6.310e-03
# [upd 400/1000] train MSE=2.531e-06  val MSE=6.098e-03
# [upd 500/1000] train MSE=1.229e-05  val MSE=6.133e-03
# [upd 600/1000] train MSE=9.715e-06  val MSE=5.996e-03
# [upd 700/1000] train MSE=1.363e-07  val MSE=5.885e-03
# [upd 800/1000] train MSE=1.366e-08  val MSE=5.884e-03
# [upd 900/1000] train MSE=1.212e-05  val MSE=5.630e-03
# [upd 1000/1000] train MSE=1.219e-08  val MSE=5.645e-03
# Test results → MSE = 4.709e-03   R² = 0.9063

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=10000,
        n_updates=500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/500] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 50/500] train MSE=3.526e-03  val MSE=6.032e-03
# [upd 100/500] train MSE=6.719e-04  val MSE=8.163e-03
# [upd 150/500] train MSE=7.171e-04  val MSE=7.709e-03
# [upd 200/500] train MSE=8.183e-04  val MSE=6.930e-03
# [upd 250/500] train MSE=3.454e-05  val MSE=6.413e-03
# [upd 300/500] train MSE=4.771e-04  val MSE=6.310e-03
# [upd 350/500] train MSE=9.511e-06  val MSE=6.105e-03
# [upd 400/500] train MSE=2.531e-06  val MSE=6.098e-03
# [upd 450/500] train MSE=3.610e-06  val MSE=6.152e-03
# [upd 500/500] train MSE=1.229e-05  val MSE=6.133e-03
# Test results → MSE = 4.729e-03   R² = 0.9059

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=20000,
        n_updates=250,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/250] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 25/250] train MSE=1.185e-02  val MSE=8.047e-03
# [upd 50/250] train MSE=3.526e-03  val MSE=6.032e-03
# [upd 75/250] train MSE=1.741e-03  val MSE=8.366e-03
# [upd 100/250] train MSE=6.719e-04  val MSE=8.163e-03
# [upd 125/250] train MSE=3.409e-04  val MSE=7.941e-03
# [upd 150/250] train MSE=7.171e-04  val MSE=7.709e-03
# [upd 175/250] train MSE=1.691e-04  val MSE=6.888e-03
# [upd 200/250] train MSE=8.183e-04  val MSE=6.930e-03
# [upd 225/250] train MSE=7.371e-05  val MSE=6.515e-03
# [upd 250/250] train MSE=3.454e-05  val MSE=6.413e-03
# Test results → MSE = 4.807e-03   R² = 0.9044

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=50000,
        n_updates=100,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/100] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 10/100] train MSE=3.933e-02  val MSE=5.239e-03
# [upd 20/100] train MSE=1.519e-02  val MSE=4.238e-03
# [upd 30/100] train MSE=8.822e-03  val MSE=5.227e-03
# [upd 40/100] train MSE=5.491e-03  val MSE=6.499e-03
# [upd 50/100] train MSE=3.526e-03  val MSE=6.032e-03
# [upd 60/100] train MSE=2.310e-03  val MSE=7.679e-03
# [upd 70/100] train MSE=2.138e-03  val MSE=8.858e-03
# [upd 80/100] train MSE=1.505e-03  val MSE=8.956e-03
# [upd 90/100] train MSE=1.596e-03  val MSE=8.969e-03
# [upd 100/100] train MSE=6.719e-04  val MSE=8.163e-03
# Test results → MSE = 5.402e-03   R² = 0.8925

# %% [markdown]
# ## 6x2

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=5000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10    
    )
# Out:
# [upd 1/1000] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 100/1000] train MSE=1.558e-03  val MSE=7.658e-03
# [upd 200/1000] train MSE=1.672e-04  val MSE=7.725e-03
# [upd 300/1000] train MSE=9.853e-05  val MSE=7.302e-03
# [upd 400/1000] train MSE=1.275e-05  val MSE=6.958e-03
# [upd 500/1000] train MSE=1.595e-06  val MSE=6.761e-03
# [upd 600/1000] train MSE=5.762e-07  val MSE=6.551e-03
# [upd 700/1000] train MSE=2.522e-06  val MSE=6.402e-03
# [upd 800/1000] train MSE=7.415e-08  val MSE=6.400e-03
# [upd 900/1000] train MSE=7.399e-04  val MSE=5.737e-03
# [upd 1000/1000] train MSE=1.239e-07  val MSE=6.125e-03
# Test results → MSE = 4.961e-03   R² = 0.9013

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=10000,
        n_updates=500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/500] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 50/500] train MSE=2.742e-03  val MSE=7.004e-03
# [upd 100/500] train MSE=1.558e-03  val MSE=7.658e-03
# [upd 150/500] train MSE=3.578e-04  val MSE=7.680e-03
# [upd 200/500] train MSE=1.672e-04  val MSE=7.725e-03
# [upd 250/500] train MSE=4.640e-05  val MSE=7.707e-03
# [upd 300/500] train MSE=9.853e-05  val MSE=7.302e-03
# [upd 350/500] train MSE=2.382e-04  val MSE=7.337e-03
# [upd 400/500] train MSE=1.275e-05  val MSE=6.958e-03
# [upd 450/500] train MSE=2.887e-06  val MSE=6.763e-03
# [upd 500/500] train MSE=1.595e-06  val MSE=6.761e-03
# Test results → MSE = 4.972e-03   R² = 0.9011

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=20000,
        n_updates=250,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/250] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 50/250] train MSE=2.742e-03  val MSE=7.004e-03
# [upd 100/250] train MSE=1.558e-03  val MSE=7.658e-03
# [upd 150/250] train MSE=3.578e-04  val MSE=7.680e-03
# [upd 200/250] train MSE=1.672e-04  val MSE=7.725e-03
# [upd 250/250] train MSE=4.640e-05  val MSE=7.707e-03
# Test results → MSE = 5.019e-03   R² = 0.9001

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=50000,
        n_updates=100,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/100] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 10/100] train MSE=2.770e-02  val MSE=1.371e-02
# [upd 20/100] train MSE=1.245e-02  val MSE=5.755e-03
# [upd 30/100] train MSE=6.630e-03  val MSE=7.689e-03
# [upd 40/100] train MSE=4.204e-03  val MSE=6.673e-03
# [upd 50/100] train MSE=2.742e-03  val MSE=7.004e-03
# [upd 60/100] train MSE=2.360e-03  val MSE=7.463e-03
# [upd 70/100] train MSE=1.566e-03  val MSE=7.390e-03
# [upd 80/100] train MSE=1.118e-03  val MSE=7.493e-03
# [upd 90/100] train MSE=1.034e-03  val MSE=7.934e-03
# [upd 100/100] train MSE=1.554e-03  val MSE=7.612e-03
# Test results → MSE = 5.876e-03   R² = 0.8831

# %% [markdown]
# # Medium Testing Model (10 Epochs)

# %% [markdown]
# ## 3x4

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=5000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/10000] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 1000/10000] train MSE=8.971e-07  val MSE=4.413e-03
# [upd 2000/10000] train MSE=1.065e-08  val MSE=4.515e-03
# [upd 3000/10000] train MSE=3.903e-10  val MSE=4.522e-03
# [upd 4000/10000] train MSE=1.727e-15  val MSE=4.523e-03
# [upd 5000/10000] train MSE=4.243e-16  val MSE=4.523e-03
# [upd 6000/10000] train MSE=6.066e-16  val MSE=4.523e-03
# [upd 7000/10000] train MSE=2.618e-05  val MSE=2.645e-03
# [upd 8000/10000] train MSE=3.125e-06  val MSE=2.263e-03
# [upd 9000/10000] train MSE=5.135e-06  val MSE=2.223e-03
# [upd 10000/10000] train MSE=4.356e-07  val MSE=2.122e-03
# Test results → MSE = 5.652e-03   R² = 0.8876

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=10000,
        n_updates=5000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/5000] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 500/5000] train MSE=2.468e-04  val MSE=4.775e-03
# [upd 1000/5000] train MSE=8.971e-07  val MSE=4.413e-03
# [upd 1500/5000] train MSE=3.953e-08  val MSE=4.443e-03
# [upd 2000/5000] train MSE=1.065e-08  val MSE=4.515e-03
# [upd 2500/5000] train MSE=5.890e-10  val MSE=4.616e-03
# [upd 3000/5000] train MSE=3.903e-10  val MSE=4.522e-03
# [upd 3500/5000] train MSE=4.008e-14  val MSE=4.523e-03
# [upd 4000/5000] train MSE=1.727e-15  val MSE=4.523e-03
# [upd 4500/5000] train MSE=4.524e-16  val MSE=4.523e-03
# [upd 5000/5000] train MSE=4.243e-16  val MSE=4.523e-03
# Test results → MSE = 5.184e-03   R² = 0.8969

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=20000,
        n_updates=2500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/2500] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 250/2500] train MSE=2.715e-04  val MSE=5.334e-03
# [upd 500/2500] train MSE=2.468e-04  val MSE=4.775e-03
# [upd 750/2500] train MSE=5.448e-06  val MSE=4.458e-03
# [upd 1000/2500] train MSE=8.971e-07  val MSE=4.413e-03
# [upd 1250/2500] train MSE=1.042e-03  val MSE=6.175e-03
# [upd 1500/2500] train MSE=3.953e-08  val MSE=4.443e-03
# [upd 1750/2500] train MSE=1.411e-05  val MSE=4.339e-03
# [upd 2000/2500] train MSE=1.065e-08  val MSE=4.515e-03
# [upd 2250/2500] train MSE=7.532e-04  val MSE=4.878e-03
# [upd 2500/2500] train MSE=5.890e-10  val MSE=4.616e-03
# Test results → MSE = 5.266e-03   R² = 0.8952

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=50000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/1000] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 100/1000] train MSE=1.464e-03  val MSE=6.736e-03
# [upd 200/1000] train MSE=6.378e-04  val MSE=5.947e-03
# [upd 300/1000] train MSE=2.801e-04  val MSE=5.094e-03
# [upd 400/1000] train MSE=5.561e-05  val MSE=4.735e-03
# [upd 500/1000] train MSE=2.468e-04  val MSE=4.775e-03
# [upd 600/1000] train MSE=1.070e-04  val MSE=4.586e-03
# [upd 700/1000] train MSE=2.106e-04  val MSE=4.611e-03
# [upd 800/1000] train MSE=1.051e-04  val MSE=4.771e-03
# [upd 900/1000] train MSE=3.491e-06  val MSE=4.368e-03
# [upd 1000/1000] train MSE=8.971e-07  val MSE=4.413e-03
# Test results → MSE = 5.439e-03   R² = 0.8918

# %% [markdown]
# ## 5x 2.5

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=5000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/10000] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 1000/10000] train MSE=3.067e-03  val MSE=6.624e-03
# [upd 2000/10000] train MSE=2.699e-15  val MSE=5.289e-03
# [upd 3000/10000] train MSE=5.121e-16  val MSE=5.289e-03
# [upd 4000/10000] train MSE=4.439e-16  val MSE=5.289e-03
# [upd 5000/10000] train MSE=2.048e-05  val MSE=4.924e-03
# [upd 6000/10000] train MSE=1.225e-04  val MSE=5.182e-03
# [upd 7000/10000] train MSE=7.592e-06  val MSE=5.390e-03
# [upd 8000/10000] train MSE=6.366e-08  val MSE=5.058e-03
# [upd 9000/10000] train MSE=1.578e-06  val MSE=4.926e-03
# [upd 10000/10000] train MSE=6.383e-07  val MSE=5.053e-03
# Test results → MSE = 4.672e-03   R² = 0.9071

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=10000,
        n_updates=5000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/5000] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 500/5000] train MSE=6.110e-05  val MSE=5.856e-03
# [upd 1000/5000] train MSE=3.067e-03  val MSE=6.624e-03
# [upd 1500/5000] train MSE=4.361e-12  val MSE=5.289e-03
# [upd 2000/5000] train MSE=2.699e-15  val MSE=5.289e-03
# [upd 2500/5000] train MSE=5.583e-16  val MSE=5.289e-03
# [upd 3000/5000] train MSE=5.121e-16  val MSE=5.289e-03
# [upd 3500/5000] train MSE=4.592e-16  val MSE=5.289e-03
# [upd 4000/5000] train MSE=4.439e-16  val MSE=5.289e-03
# [upd 4500/5000] train MSE=2.233e-04  val MSE=6.417e-03
# [upd 5000/5000] train MSE=2.048e-05  val MSE=4.924e-03
# Test results → MSE = 4.872e-03   R² = 0.9031

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=20000,
        n_updates=2500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/2500] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 250/2500] train MSE=3.449e-05  val MSE=6.653e-03
# [upd 500/2500] train MSE=6.110e-05  val MSE=5.856e-03
# [upd 750/2500] train MSE=1.898e-07  val MSE=5.658e-03
# [upd 1000/2500] train MSE=3.067e-03  val MSE=6.624e-03
# [upd 1250/2500] train MSE=3.660e-09  val MSE=5.284e-03
# [upd 1500/2500] train MSE=4.361e-12  val MSE=5.289e-03
# [upd 1750/2500] train MSE=2.472e-14  val MSE=5.289e-03
# [upd 2000/2500] train MSE=2.699e-15  val MSE=5.289e-03
# [upd 2250/2500] train MSE=9.796e-16  val MSE=5.289e-03
# [upd 2500/2500] train MSE=5.583e-16  val MSE=5.289e-03
# Test results → MSE = 4.709e-03   R² = 0.9063

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=50000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/1000] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 100/1000] train MSE=6.720e-04  val MSE=8.202e-03
# [upd 200/1000] train MSE=8.808e-05  val MSE=7.062e-03
# [upd 300/1000] train MSE=3.285e-05  val MSE=6.512e-03
# [upd 400/1000] train MSE=5.613e-06  val MSE=6.053e-03
# [upd 500/1000] train MSE=6.110e-05  val MSE=5.856e-03
# [upd 600/1000] train MSE=2.379e-07  val MSE=5.949e-03
# [upd 700/1000] train MSE=2.922e-06  val MSE=5.638e-03
# [upd 800/1000] train MSE=4.589e-08  val MSE=5.652e-03
# [upd 900/1000] train MSE=3.637e-09  val MSE=5.650e-03
# [upd 1000/1000] train MSE=3.067e-03  val MSE=6.624e-03
# Test results → MSE = 7.997e-03   R² = 0.8409

# %% [markdown]
# ## 6x2

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=5000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/10000] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 1000/10000] train MSE=1.239e-07  val MSE=6.125e-03
# [upd 2000/10000] train MSE=2.692e-12  val MSE=5.665e-03
# [upd 3000/10000] train MSE=8.205e-16  val MSE=5.665e-03
# [upd 4000/10000] train MSE=6.515e-16  val MSE=5.665e-03
# [upd 5000/10000] train MSE=6.767e-04  val MSE=5.153e-03
# [upd 6000/10000] train MSE=7.076e-07  val MSE=3.907e-03
# [upd 7000/10000] train MSE=1.793e-08  val MSE=3.710e-03
# [upd 8000/10000] train MSE=5.509e-08  val MSE=3.617e-03
# [upd 9000/10000] train MSE=4.406e-09  val MSE=3.313e-03
# [upd 10000/10000] train MSE=4.941e-14  val MSE=3.302e-03
# Test results → MSE = 5.388e-03   R² = 0.8928

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=10000,
        n_updates=5000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/5000] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 500/5000] train MSE=1.595e-06  val MSE=6.761e-03
# [upd 1000/5000] train MSE=1.239e-07  val MSE=6.125e-03
# [upd 1500/5000] train MSE=3.255e-09  val MSE=5.751e-03
# [upd 2000/5000] train MSE=2.692e-12  val MSE=5.665e-03
# [upd 2500/5000] train MSE=3.582e-15  val MSE=5.665e-03
# [upd 3000/5000] train MSE=8.205e-16  val MSE=5.665e-03
# [upd 3500/5000] train MSE=5.390e-16  val MSE=5.665e-03
# [upd 4000/5000] train MSE=6.515e-16  val MSE=5.665e-03
# [upd 4500/5000] train MSE=8.361e-16  val MSE=5.665e-03
# [upd 5000/5000] train MSE=6.767e-04  val MSE=5.153e-03
# Test results → MSE = 5.578e-03   R² = 0.8890

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=20000,
        n_updates=2500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/2500] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 250/2500] train MSE=4.640e-05  val MSE=7.707e-03
# [upd 500/2500] train MSE=1.595e-06  val MSE=6.761e-03
# [upd 750/2500] train MSE=2.220e-07  val MSE=6.380e-03
# [upd 1000/2500] train MSE=1.239e-07  val MSE=6.125e-03
# [upd 1250/2500] train MSE=1.430e-06  val MSE=5.759e-03
# [upd 1500/2500] train MSE=3.255e-09  val MSE=5.751e-03
# [upd 1750/2500] train MSE=1.601e-09  val MSE=5.669e-03
# [upd 2000/2500] train MSE=2.692e-12  val MSE=5.665e-03
# [upd 2250/2500] train MSE=3.111e-14  val MSE=5.665e-03
# [upd 2500/2500] train MSE=3.582e-15  val MSE=5.665e-03
# Test results → MSE = 4.992e-03   R² = 0.9007

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=50000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/1000] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 100/1000] train MSE=1.558e-03  val MSE=7.658e-03
# [upd 200/1000] train MSE=1.672e-04  val MSE=7.725e-03
# [upd 300/1000] train MSE=9.853e-05  val MSE=7.302e-03
# [upd 400/1000] train MSE=1.275e-05  val MSE=6.958e-03
# [upd 500/1000] train MSE=1.595e-06  val MSE=6.761e-03
# [upd 600/1000] train MSE=5.762e-07  val MSE=6.551e-03
# [upd 700/1000] train MSE=2.522e-06  val MSE=6.402e-03
# [upd 800/1000] train MSE=7.415e-08  val MSE=6.400e-03
# [upd 900/1000] train MSE=7.399e-04  val MSE=5.737e-03
# [upd 1000/1000] train MSE=1.239e-07  val MSE=6.125e-03
# Test results → MSE = 4.961e-03   R² = 0.9013

# %% [markdown]
# # Large Testing Model (100 Epochs)

# %% [markdown]
# ## 3x4

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=5000,
        n_updates=100000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/100000] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 10000/100000] train MSE=8.715e-10  val MSE=4.543e-03
# [upd 20000/100000] train MSE=1.362e-10  val MSE=3.179e-03
# [upd 30000/100000] train MSE=3.035e-16  val MSE=3.229e-03
# [upd 40000/100000] train MSE=1.962e-16  val MSE=2.613e-03
# [upd 50000/100000] train MSE=1.944e-16  val MSE=3.103e-03
# [upd 60000/100000] train MSE=8.825e-12  val MSE=3.249e-03
# [upd 70000/100000] train MSE=3.496e-16  val MSE=3.600e-03
# [upd 80000/100000] train MSE=2.891e-16  val MSE=4.444e-03
# [upd 90000/100000] train MSE=6.108e-16  val MSE=5.361e-03
# [upd 100000/100000] train MSE=7.527e-16  val MSE=5.731e-03
# Test results → MSE = 7.435e-03   R² = 0.8521

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=10000,
        n_updates=50000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/50000] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 5000/50000] train MSE=4.469e-16  val MSE=4.616e-03
# [upd 10000/50000] train MSE=8.715e-10  val MSE=4.543e-03
# [upd 15000/50000] train MSE=1.275e-06  val MSE=2.884e-03
# [upd 20000/50000] train MSE=1.362e-10  val MSE=3.179e-03
# [upd 25000/50000] train MSE=1.717e-15  val MSE=3.456e-03
# [upd 30000/50000] train MSE=3.035e-16  val MSE=3.229e-03
# [upd 35000/50000] train MSE=8.517e-13  val MSE=2.627e-03
# [upd 40000/50000] train MSE=1.962e-16  val MSE=2.613e-03
# [upd 45000/50000] train MSE=4.274e-16  val MSE=2.957e-03
# [upd 50000/50000] train MSE=1.944e-16  val MSE=3.103e-03
# Test results → MSE = 5.794e-03   R² = 0.8847

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=20000,
        n_updates=25000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/25000] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 2500/25000] train MSE=2.788e-08  val MSE=4.639e-03
# [upd 5000/25000] train MSE=4.469e-16  val MSE=4.616e-03
# [upd 7500/25000] train MSE=4.919e-07  val MSE=5.405e-03
# [upd 10000/25000] train MSE=8.715e-10  val MSE=4.543e-03
# [upd 12500/25000] train MSE=9.500e-13  val MSE=4.167e-03
# [upd 15000/25000] train MSE=1.275e-06  val MSE=2.884e-03
# [upd 17500/25000] train MSE=9.771e-13  val MSE=2.850e-03
# [upd 20000/25000] train MSE=1.362e-10  val MSE=3.179e-03
# [upd 22500/25000] train MSE=1.767e-16  val MSE=3.157e-03
# [upd 25000/25000] train MSE=1.717e-15  val MSE=3.456e-03
# Test results → MSE = 3.963e-03   R² = 0.9212

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=50000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/10000] train MSE=2.411e-01  val MSE=3.723e-01
# [upd 1000/10000] train MSE=4.342e-07  val MSE=4.562e-03
# [upd 2000/10000] train MSE=1.141e-09  val MSE=4.720e-03
# [upd 3000/10000] train MSE=8.079e-13  val MSE=4.616e-03
# [upd 4000/10000] train MSE=9.087e-16  val MSE=4.616e-03
# [upd 5000/10000] train MSE=4.469e-16  val MSE=4.616e-03
# [upd 6000/10000] train MSE=5.133e-05  val MSE=5.886e-03
# [upd 7000/10000] train MSE=3.367e-07  val MSE=5.476e-03
# [upd 8000/10000] train MSE=2.472e-08  val MSE=5.064e-03
# [upd 9000/10000] train MSE=3.950e-08  val MSE=4.629e-03
# [upd 10000/10000] train MSE=8.715e-10  val MSE=4.543e-03
# Test results → MSE = 4.428e-03   R² = 0.9119

# %% [markdown]
# ## 5x 2.5

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=5000,
        n_updates=100000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/100000] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 10000/100000] train MSE=3.362e-11  val MSE=6.827e-03
# [upd 20000/100000] train MSE=2.029e-08  val MSE=4.587e-03
# [upd 30000/100000] train MSE=1.088e-15  val MSE=3.064e-03
# [upd 40000/100000] train MSE=1.960e-10  val MSE=3.387e-03
# [upd 50000/100000] train MSE=4.205e-16  val MSE=3.795e-03
# [upd 60000/100000] train MSE=4.089e-16  val MSE=4.315e-03
# [upd 70000/100000] train MSE=3.655e-11  val MSE=5.346e-03
# [upd 80000/100000] train MSE=2.713e-12  val MSE=5.980e-03
# [upd 90000/100000] train MSE=1.662e-10  val MSE=5.990e-03
# [upd 100000/100000] train MSE=3.099e-10  val MSE=4.922e-03
# Test results → MSE = 7.815e-03   R² = 0.8445

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=10000,
        n_updates=50000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/50000] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 5000/50000] train MSE=3.958e-05  val MSE=6.355e-03
# [upd 10000/50000] train MSE=3.362e-11  val MSE=6.827e-03
# [upd 15000/50000] train MSE=1.831e-07  val MSE=4.582e-03
# [upd 20000/50000] train MSE=2.029e-08  val MSE=4.587e-03
# [upd 25000/50000] train MSE=1.768e-08  val MSE=3.378e-03
# [upd 30000/50000] train MSE=1.088e-15  val MSE=3.064e-03
# [upd 35000/50000] train MSE=4.432e-09  val MSE=3.499e-03
# [upd 40000/50000] train MSE=1.960e-10  val MSE=3.387e-03
# [upd 45000/50000] train MSE=7.439e-14  val MSE=3.841e-03
# [upd 50000/50000] train MSE=4.205e-16  val MSE=3.795e-03
# Test results → MSE = 5.629e-03   R² = 0.8880

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=20000,
        n_updates=25000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/25000] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 2500/25000] train MSE=7.710e-16  val MSE=5.361e-03
# [upd 5000/25000] train MSE=3.958e-05  val MSE=6.355e-03
# [upd 7500/25000] train MSE=2.548e-07  val MSE=6.910e-03
# [upd 10000/25000] train MSE=3.362e-11  val MSE=6.827e-03
# [upd 12500/25000] train MSE=3.500e-02  val MSE=3.769e-02
# [upd 15000/25000] train MSE=1.831e-07  val MSE=4.582e-03
# [upd 17500/25000] train MSE=1.119e-08  val MSE=4.630e-03
# [upd 20000/25000] train MSE=2.029e-08  val MSE=4.587e-03
# [upd 22500/25000] train MSE=2.365e-11  val MSE=4.548e-03
# [upd 25000/25000] train MSE=1.768e-08  val MSE=3.378e-03
# Test results → MSE = 4.687e-03   R² = 0.9068

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=50000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/10000] train MSE=7.121e-02  val MSE=2.383e-01
# [upd 1000/10000] train MSE=3.494e-04  val MSE=5.111e-03
# [upd 2000/10000] train MSE=5.739e-15  val MSE=5.361e-03
# [upd 3000/10000] train MSE=5.111e-16  val MSE=5.361e-03
# [upd 4000/10000] train MSE=5.360e-16  val MSE=5.361e-03
# [upd 5000/10000] train MSE=3.958e-05  val MSE=6.355e-03
# [upd 6000/10000] train MSE=6.756e-07  val MSE=6.541e-03
# [upd 7000/10000] train MSE=9.237e-08  val MSE=6.825e-03
# [upd 8000/10000] train MSE=5.013e-08  val MSE=6.945e-03
# [upd 9000/10000] train MSE=6.208e-07  val MSE=6.787e-03
# [upd 10000/10000] train MSE=3.362e-11  val MSE=6.827e-03
# Test results → MSE = 4.662e-03   R² = 0.9073

# %% [markdown]
# ## 6x2

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=5000,
        n_updates=100000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/100000] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 10000/100000] train MSE=6.387e-08  val MSE=5.080e-03
# [upd 20000/100000] train MSE=5.250e-10  val MSE=2.990e-03
# [upd 30000/100000] train MSE=7.613e-09  val MSE=2.905e-03
# [upd 40000/100000] train MSE=8.280e-11  val MSE=4.103e-03
# [upd 50000/100000] train MSE=3.742e-15  val MSE=4.482e-03
# [upd 60000/100000] train MSE=8.841e-16  val MSE=2.875e-03
# [upd 70000/100000] train MSE=9.399e-16  val MSE=3.384e-03
# [upd 80000/100000] train MSE=8.400e-10  val MSE=3.411e-03
# [upd 90000/100000] train MSE=1.367e-14  val MSE=3.625e-03
# [upd 100000/100000] train MSE=1.909e-10  val MSE=3.899e-03
# Test results → MSE = 8.682e-03   R² = 0.8273

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=10000,
        n_updates=50000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/50000] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 5000/50000] train MSE=1.004e-03  val MSE=7.273e-03
# [upd 10000/50000] train MSE=6.387e-08  val MSE=5.080e-03
# [upd 15000/50000] train MSE=3.536e-06  val MSE=3.946e-03
# [upd 20000/50000] train MSE=5.250e-10  val MSE=2.990e-03
# [upd 25000/50000] train MSE=2.822e-14  val MSE=4.230e-03
# [upd 30000/50000] train MSE=7.613e-09  val MSE=2.905e-03
# [upd 35000/50000] train MSE=3.697e-09  val MSE=2.660e-03
# [upd 40000/50000] train MSE=8.280e-11  val MSE=4.103e-03
# [upd 45000/50000] train MSE=4.670e-11  val MSE=4.525e-03
# [upd 50000/50000] train MSE=3.742e-15  val MSE=4.482e-03
# Test results → MSE = 6.566e-03   R² = 0.8694

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=20000,
        n_updates=25000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/25000] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 2500/25000] train MSE=5.876e-15  val MSE=6.051e-03
# [upd 5000/25000] train MSE=1.004e-03  val MSE=7.273e-03
# [upd 7500/25000] train MSE=5.558e-06  val MSE=5.308e-03
# [upd 10000/25000] train MSE=6.387e-08  val MSE=5.080e-03
# [upd 12500/25000] train MSE=1.831e-08  val MSE=4.244e-03
# [upd 15000/25000] train MSE=3.536e-06  val MSE=3.946e-03
# [upd 17500/25000] train MSE=1.277e-14  val MSE=3.671e-03
# [upd 20000/25000] train MSE=5.250e-10  val MSE=2.990e-03
# [upd 22500/25000] train MSE=4.446e-07  val MSE=4.078e-03
# [upd 25000/25000] train MSE=2.822e-14  val MSE=4.230e-03
# Test results → MSE = 5.018e-03   R² = 0.9002

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=50000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/10000] train MSE=1.051e-01  val MSE=7.256e-02
# [upd 1000/10000] train MSE=2.575e-08  val MSE=6.658e-03
# [upd 2000/10000] train MSE=3.069e-12  val MSE=6.051e-03
# [upd 3000/10000] train MSE=7.746e-16  val MSE=6.051e-03
# [upd 4000/10000] train MSE=7.835e-16  val MSE=6.051e-03
# [upd 5000/10000] train MSE=1.004e-03  val MSE=7.273e-03
# [upd 6000/10000] train MSE=1.415e-05  val MSE=5.574e-03
# [upd 7000/10000] train MSE=1.561e-06  val MSE=5.449e-03
# [upd 8000/10000] train MSE=9.344e-06  val MSE=5.148e-03
# [upd 9000/10000] train MSE=1.082e-07  val MSE=5.221e-03
# [upd 10000/10000] train MSE=6.387e-08  val MSE=5.080e-03
# Test results → MSE = 5.538e-03   R² = 0.8898

# %% [markdown]
# # Adjusting Depth and Width

# %%
run_experiment_updates_per_update(
        width=1600,
        layers=6,
        batch_size=5000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/10000] train MSE=1.584e-01  val MSE=4.354e+01
# [upd 1000/10000] train MSE=6.250e-04  val MSE=4.457e-03
# [upd 2000/10000] train MSE=8.684e-07  val MSE=3.222e-03
# [upd 3000/10000] train MSE=6.157e-07  val MSE=3.392e-03
# [upd 4000/10000] train MSE=2.351e-10  val MSE=3.404e-03
# [upd 5000/10000] train MSE=2.523e-12  val MSE=3.267e-03
# [upd 6000/10000] train MSE=1.788e-16  val MSE=3.267e-03
# [upd 7000/10000] train MSE=1.343e-10  val MSE=4.024e-03
# [upd 8000/10000] train MSE=3.287e-16  val MSE=4.023e-03
# [upd 9000/10000] train MSE=5.043e-05  val MSE=3.019e-03
# [upd 10000/10000] train MSE=3.982e-06  val MSE=3.607e-03
# Test results → MSE = 3.766e-03   R² = 0.9251
