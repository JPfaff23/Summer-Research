# %% [markdown]
# # Initial Analysis of Data

# %%
import pandas as pd
Train_Raw = pd.read_parquet("Train_5m.parquet")
Test_Raw = pd.read_parquet("Test_5k.parquet")

# %%
Train_Raw.describe()
# Out:
#                S0_0          S0_1          S0_2       sigma_0       sigma_1  \
# count  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06
# mean   1.868607e+02  1.868605e+02  1.868165e+02  5.000531e-01  5.001468e-01
# std    9.958846e+01  9.967165e+01  9.957335e+01  2.887234e-01  2.886410e-01
# min    1.172166e+01  1.339653e+01  1.352048e+01  1.947196e-07  1.227992e-08
# 25%    1.176948e+02  1.177294e+02  1.176408e+02  2.500339e-01  2.503857e-01
# 50%    1.649082e+02  1.648561e+02  1.648720e+02  5.001459e-01  5.001793e-01
# 75%    2.310593e+02  2.309599e+02  2.309787e+02  7.502468e-01  7.501256e-01
# max    2.253572e+03  2.463150e+03  2.094249e+03  9.999996e-01  9.999998e-01
#
#             sigma_2      corr_0_1      corr_0_2      corr_1_2          K  \
# count  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06  5000000.0
# mean   4.998487e-01  4.284284e-01  4.288081e-01  4.777857e-01      100.0
# std    2.885436e-01  3.195096e-01  3.193338e-01  2.860526e-01        0.0
# min    3.966500e-09 -9.418687e-01 -9.540399e-01 -8.868241e-01      100.0
# 25%    2.500368e-01  2.210713e-01  2.211613e-01  2.986871e-01      100.0
# 50%    4.998605e-01  4.709321e-01  4.714426e-01  5.194424e-01      100.0
# 75%    7.495205e-01  6.776692e-01  6.779694e-01  6.979728e-01      100.0
# max    9.999997e-01  9.997548e-01  9.996756e-01  9.988353e-01      100.0
#
#                   r             T         price      price_se
# count  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06
# mean   3.000000e-02  2.531572e+00  2.011008e+01  3.499769e-02
# std    1.040834e-16  2.234199e+00  2.233768e+01  3.523127e-02
# min    3.000000e-02  3.968254e-03  0.000000e+00  0.000000e+00
# 25%    3.000000e-02  4.801587e-01  4.959547e+00  1.153310e-02
# 50%    3.000000e-02  1.920635e+00  1.342361e+01  2.709245e-02
# 75%    3.000000e-02  4.321429e+00  2.734354e+01  4.798369e-02
# max    3.000000e-02  7.337302e+00  3.994805e+02  2.747604e+00

# %%
Test_Raw.describe()
# Out:
#               S0_0         S0_1         S0_2      sigma_0      sigma_1  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean    188.689862   189.040646   187.735662     0.498777     0.498378
# std     101.421903   102.394865   100.238265     0.288034     0.288390
# min      33.114428    24.450447    31.180010     0.000333     0.000053
# 25%     118.007348   117.267481   117.038329     0.247445     0.251761
# 50%     165.808940   165.396263   164.323097     0.504016     0.494027
# 75%     233.421687   233.927115   233.070243     0.743756     0.748565
# max     859.235205  1046.200883   974.763679     0.999818     0.999874
#
#            sigma_2     corr_0_1     corr_0_2     corr_1_2       K        r  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.0  5000.00
# mean      0.502909     0.426164     0.427507     0.476203   100.0     0.03
# std       0.289537     0.327460     0.318340     0.287172     0.0     0.00
# min       0.000836    -0.761601    -0.662609    -0.663499   100.0     0.03
# 25%       0.252353     0.213616     0.216133     0.294875   100.0     0.03
# 50%       0.506280     0.476555     0.468948     0.519231   100.0     0.03
# 75%       0.750685     0.684222     0.678560     0.699700   100.0     0.03
# max       0.999893     0.995830     0.988042     0.986641   100.0     0.03
#
#                  T        price     price_se
# count  5000.000000  5000.000000  5000.000000
# mean      2.583890    20.510019     0.003578
# std       2.239724    23.122587     0.003487
# min       0.003968     0.000000     0.000000
# 25%       0.571429     5.384689     0.001218
# 50%       1.920635    13.603859     0.002732
# 75%       4.321429    27.350641     0.004854
# max       7.337302   230.354542     0.036428

# %%
Train_Raw.head()
# Out:
#          S0_0        S0_1        S0_2   sigma_0   sigma_1   sigma_2  corr_0_1  \
# 0  211.352480  153.859221  227.924505  0.156019  0.155995  0.058084  0.595795
# 1  112.300907  162.868414  196.949203  0.859940  0.680308  0.450499  0.040739
# 2  661.378774  299.462754  183.917878  0.921874  0.088493  0.195983  0.542316
# 3  143.670105  226.630908  104.774440  0.790176  0.605960  0.926301  0.323487
# 4  111.644447  108.117868  152.918218  0.201719  0.895764  0.475370  0.160354
#
#    corr_0_2  corr_1_2      K     r         T      price  price_se
# 0  0.267429  0.404955  100.0  0.03  2.285714  59.088424  0.034197
# 1  0.310864  0.304059  100.0  0.03  1.285714  11.365275  0.032726
# 2  0.920858  0.695307  100.0  0.03  6.349206  58.428852  0.094115
# 3  0.165483  0.568074  100.0  0.03  6.670635   4.779279  0.051336
# 4  0.201242  0.880389  100.0  0.03  4.063492   6.204275  0.020843

# %%
Test_Raw.head()
# Out:
#          S0_0        S0_1        S0_2   sigma_0   sigma_1   sigma_2  corr_0_1  \
# 0  211.352480  153.859221  227.924505  0.156019  0.155995  0.058084  0.595795
# 1  112.300907  162.868414  196.949203  0.859940  0.680308  0.450499  0.040739
# 2  661.378774  299.462754  183.917878  0.921874  0.088493  0.195983  0.542316
# 3  143.670105  226.630908  104.774440  0.790176  0.605960  0.926301  0.323487
# 4  111.644447  108.117868  152.918218  0.201719  0.895764  0.475370  0.160354
#
#    corr_0_2  corr_1_2      K     r         T      price  price_se
# 0  0.267429  0.404955  100.0  0.03  2.285714  59.114475  0.003422
# 1  0.310864  0.304059  100.0  0.03  1.285714  11.351699  0.003264
# 2  0.920858  0.695307  100.0  0.03  6.349206  58.343190  0.009409
# 3  0.165483  0.568074  100.0  0.03  6.670635   4.867073  0.005575
# 4  0.201242  0.880389  100.0  0.03  4.063492   6.194364  0.002086

# %% [markdown]
# # Initial Data Cleaning

# %%
import pandas as pd
from pathlib import Path

def clean_parquet(src_path, dst_path):
    """
    • Divides every S0_* and price by the row’s K
    • Renames the results to `S0_i/K` and `price/k`
    • Removes *_se, the raw S0_*, price, and K columns
    • Drops rows where price/k < 1e-6
    """
    df = pd.read_parquet(src_path)

    # 1) locate relevant columns
    s0_cols = [c for c in df.columns if c.lower().startswith("s0_")]
    se_cols = [c for c in df.columns if c.endswith("_se")]

    # 2) create scaled columns with the requested names
    for col in s0_cols:
        df[f"{col}/K"] = df[col] / df["K"]
    df["price/k"] = df["price"] / df["K"]

    # 3) filter out extremely small payoffs
    df = df[df["price/k"] >= 1e-6]

    # 4) drop the original, now-redundant columns
    df = df.drop(columns=s0_cols + ["price", "K"] + se_cols)

    # 5) save the cleaned file
    df.to_parquet(dst_path, index=False)
    print(f"✔ Saved cleaned file → {dst_path!s}")

# Apply to both datasets
clean_parquet("Train_5m.parquet", "Train_Clean_5m.parquet")
clean_parquet("Test_5k.parquet",  "Test_Clean_5k.parquet")
# Out:
# ✔ Saved cleaned file → Train_Clean_5m.parquet
# ✔ Saved cleaned file → Test_Clean_5k.parquet

# %%
Train= pd.read_parquet("Train_Clean_5m.parquet")
Test= pd.read_parquet("Test_Clean_5k.parquet")

Train.describe()
# Out:
#             sigma_0       sigma_1       sigma_2      corr_0_1      corr_0_2  \
# count  4.791421e+06  4.791421e+06  4.791421e+06  4.791421e+06  4.791421e+06
# mean   5.042429e-01  5.043056e-01  5.039476e-01  4.285833e-01  4.289856e-01
# std    2.872380e-01  2.871443e-01  2.870861e-01  3.193775e-01  3.191916e-01
# min    1.947196e-07  1.755061e-07  3.966500e-09 -9.418687e-01 -9.540399e-01
# 25%    2.566054e-01  2.568784e-01  2.564750e-01  2.213163e-01  2.213608e-01
# 50%    5.052716e-01  5.053180e-01  5.049216e-01  4.710423e-01  4.715490e-01
# 75%    7.530834e-01  7.528974e-01  7.522741e-01  6.777452e-01  6.780199e-01
# max    9.999996e-01  9.999998e-01  9.999997e-01  9.997548e-01  9.996756e-01
#
#            corr_1_2             r             T        S0_0/K        S0_1/K  \
# count  4.791421e+06  4.791421e+06  4.791421e+06  4.791421e+06  4.791421e+06
# mean   4.779681e-01  3.000000e-02  2.610050e+00  1.885631e+00  1.885544e+00
# std    2.859186e-01  1.561251e-16  2.232042e+00  9.924803e-01  9.933781e-01
# min   -8.868241e-01  3.000000e-02  3.968254e-03  1.476079e-01  1.359094e-01
# 25%    2.989228e-01  3.000000e-02  5.714286e-01  1.196093e+00  1.196282e+00
# 50%    5.196185e-01  3.000000e-02  2.099206e+00  1.663721e+00  1.662773e+00
# 75%    6.980548e-01  3.000000e-02  4.321429e+00  2.323236e+00  2.322319e+00
# max    9.988353e-01  3.000000e-02  7.337302e+00  2.253572e+01  2.463150e+01
#
#              S0_2/K       price/k
# count  4.791421e+06  4.791421e+06
# mean   1.884968e+00  2.098551e-01
# std    9.920128e-01  2.241254e-01
# min    1.599334e-01  1.000259e-06
# 25%    1.195513e+00  5.914015e-02
# 50%    1.663067e+00  1.426950e-01
# 75%    2.322676e+00  2.822896e-01
# max    2.094249e+01  3.994805e+00

# %%
Test.describe()
# Out:
#            sigma_0      sigma_1      sigma_2     corr_0_1     corr_0_2  \
# count  4806.000000  4806.000000  4806.000000  4806.000000  4806.000000
# mean      0.501998     0.502566     0.507097     0.425581     0.427767
# std       0.286955     0.286725     0.288472     0.328104     0.318288
# min       0.000333     0.000053     0.000836    -0.761601    -0.662609
# 25%       0.251825     0.257010     0.257420     0.214096     0.216432
# 50%       0.507865     0.498502     0.511137     0.475292     0.469696
# 75%       0.748894     0.752009     0.753233     0.683271     0.679360
# max       0.999818     0.999874     0.999893     0.995830     0.988042
#
#           corr_1_2             r            T       S0_0/K       S0_1/K  \
# count  4806.000000  4.806000e+03  4806.000000  4806.000000  4806.000000
# mean      0.475566  3.000000e-02     2.653786     1.897888     1.908731
# std       0.287099  3.469808e-18     2.235038     1.007901     1.013513
# min      -0.663499  3.000000e-02     0.003968     0.331144     0.280697
# 25%       0.292480  3.000000e-02     0.670635     1.202360     1.194554
# 50%       0.518427  3.000000e-02     2.099206     1.665683     1.678386
# 75%       0.699925  3.000000e-02     4.321429     2.336873     2.352377
# max       0.986641  3.000000e-02     7.337302     8.592352    10.462009
#
#             S0_2/K      price/k
# count  4806.000000  4806.000000
# mean      1.891430     0.213379
# std       1.001821     0.232071
# min       0.311800     0.000001
# 25%       1.182311     0.062184
# 50%       1.655248     0.143571
# 75%       2.340395     0.282481
# max       9.747637     2.303545

# %% [markdown]
# # Neural Network

# %%
# Cell 1 — imports & device setup
import os, math, random, time, pathlib, re
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

from torchmetrics import R2Score

# Use inline plots
# %matplotlib inline

os.environ.setdefault("NCCL_P2P_LEVEL", "0")
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on:", DEVICE)

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# Cell 2 — load & split cleaned Parquet into train/val/test TensorDatasets

# 1) Read cleaned Parquet files
#    (assumes you have already run clean_parquet on Train.parquet and Test100M.parquet)
train_df = pd.read_parquet("Train_clean_5m.parquet", engine="pyarrow")
test_df  = pd.read_parquet("Test_clean_5k.parquet", engine="pyarrow")

# 2) Split train_df → 80% train, 20% validation
X_full = train_df.drop(columns=["price/k"]).values.astype(np.float32)
y_full = train_df["price/k"].values.astype(np.float32)
X_tr_np, X_val_np, y_tr_np, y_val_np = train_test_split(
    X_full, y_full, test_size=0.01, random_state=42
)

# 3) Build TensorDatasets
train_ds = TensorDataset(torch.from_numpy(X_tr_np), torch.from_numpy(y_tr_np))
val_ds   = TensorDataset(torch.from_numpy(X_val_np), torch.from_numpy(y_val_np))
test_ds  = TensorDataset(
    torch.from_numpy(test_df.drop(columns=["price/k"]).values.astype(np.float32)),
    torch.from_numpy(test_df["price/k"].values.astype(np.float32))
)

print(f"train {len(train_ds):,} rows")
print(f"valid {len(val_ds):,} rows")
print(f" test {len(test_ds):,} rows")
# Out:
# Running on: cuda
# train 4,743,506 rows
# valid 47,915 rows
#  test 4,806 rows

# %%
# Cell 3 — define the MLP (BasketNet) model

class BasketNet(nn.Module):
    def __init__(self, in_dim: int, width: int, layers: int):
        """
        in_dim = number of input features
        width  = nodes per hidden layer
        layers = number of hidden layers
        """
        super().__init__()
        blocks = [nn.Linear(in_dim, width), nn.ReLU()]
        for _ in range(layers - 1):
            blocks += [nn.Linear(width, width), nn.ReLU()]
        blocks.append(nn.Linear(width, 1))
        self.net = nn.Sequential(*blocks)

        # Xavier initialization
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        return self.net(x)


def run_experiment_updates_per_update(
    width: int = 300,
    layers: int = 4,
    batch_size: int = 50_000,
    n_updates: int = 100_000,     # total mini‐batch updates
    lr: float = 1e-3,
    optimizer_name: str = "Adam",
    seed: int = 42,
    save_model: bool = False,      # ← new flag
    log_every: int = 1             # record every `log_every` updates
):
    """
    Train for exactly n_updates mini‐batches, recording
    train/val MSE at each update, then evaluate on test set.

    Args:
      width, layers:    model architecture
      batch_size:       mini‐batch size
      n_updates:        total optimizer steps (updates)
      lr:               learning rate
      optimizer_name:   "Adam" | "SGD" | "LBFGS"
      seed:             random seed
      save_model:       if True, save final weights to disk
      log_every:        record/compute validation every log_every steps
    """
    # 5.1) Re‐seed for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    # 5.2) Build DataLoaders
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False, pin_memory=True)
    test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False, pin_memory=True)

    # 5.3) Instantiate the model
    in_dim = train_ds[0][0].shape[0]
    model = BasketNet(in_dim, width, layers).to(DEVICE)
    if DEVICE.type == "cuda" and torch.cuda.device_count() > 1:
        model = nn.DataParallel(model)

    # 5.4) Loss & optimizer
    criterion = nn.MSELoss()
    if optimizer_name == "Adam":
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif optimizer_name == "SGD":
        optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    elif optimizer_name == "LBFGS":
        optimizer = optim.LBFGS(model.parameters(), lr=lr, max_iter=20)
    else:
        raise ValueError(f"Unknown optimizer: {optimizer_name}")

    # 5.5) Create an infinite iterator over shuffled train_loader
    def infinite_train_iter(loader):
        while True:
            for batch in loader:
                yield batch

    inf_train = infinite_train_iter(train_loader)

    # 5.6) Storage for train/val losses
    train_losses   = []
    valid_losses   = []
    steps_recorded = []

    # decide how often to print (every 10% of total updates)
    print_every = max(1, n_updates // 10)

    # 5.7) Main loop: exactly n_updates optimizer steps
    model.train()
    for step in range(1, n_updates + 1):
        # ----- 1) one optimizer step -----
        Xb, yb = next(inf_train)
        Xb, yb = Xb.to(DEVICE), yb.to(DEVICE).unsqueeze(1)
        optimizer.zero_grad(set_to_none=True)
        out       = model(Xb)
        loss      = criterion(out, yb)
        loss.backward()
        optimizer.step()
        loss_train = loss.item()

        # ----- 2) record & validate every log_every steps -----
        if step == 1 or step == n_updates or (step % log_every == 0):
            # validation pass
            model.eval()
            tot_val, cnt_val = 0.0, 0
            with torch.no_grad():
                for Xv, yv in val_loader:
                    Xv, yv = Xv.to(DEVICE), yv.to(DEVICE).unsqueeze(1)
                    ov = model(Xv)
                    tot_val += criterion(ov, yv).item() * Xv.size(0)
                    cnt_val += Xv.size(0)
            val_mse = tot_val / cnt_val

            # stash losses
            steps_recorded.append(step)
            train_losses.append(loss_train)
            valid_losses.append(val_mse)

            model.train()

            # ----- 3) print only at the first, last, or each 10% milestone -----
            if step == 1 or step == n_updates or (step % print_every == 0):
                print(f"[upd {step}/{n_updates}] "
                      f"train MSE={loss_train:.3e}  val MSE={val_mse:.3e}")

    # ---- 4) plot on the down-sampled grid ----
    train_min = np.minimum.accumulate(train_losses)
    valid_min = np.minimum.accumulate(valid_losses)

    plt.figure(figsize=(7, 4))
    plt.plot(steps_recorded, np.log10(train_min), label="train (cum-min)")
    plt.plot(steps_recorded, np.log10(valid_min), label="valid (cum-min)")
    plt.xlabel("update step")
    plt.ylabel("log10 MSE")
    plt.title(f"{layers}×{width} • bs={batch_size} • {optimizer_name}")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # 5.9) Final test‐set evaluation
    model.eval()
    all_preds, all_truths = [], []
    with torch.no_grad():
        for Xb, yb in test_loader:
            pr = model(Xb.to(DEVICE)).cpu().squeeze()
            all_preds.append(pr)
            all_truths.append(yb)
    preds  = torch.cat(all_preds)
    truths = torch.cat(all_truths)
    test_mse = criterion(preds.unsqueeze(1), truths.unsqueeze(1)).item()
    test_r2  = R2Score()(preds, truths).cpu().item()
    print(f"\nTest results → MSE = {test_mse:.3e}   R² = {test_r2:.4f}")

    # 5.10) Optionally save model weights
    if save_model:
        tag = f"w{width}_L{layers}_bs{batch_size}_upd{n_updates}_" \
              f"{optimizer_name}_lr{lr:g}"
        torch.save(model.state_dict(), f"model_{tag}.pt")
        print(f"Saved model to model_{tag}.pt")

# %% [markdown]
# # Inital Testing Model (1 epoch)

# %% [markdown]
# ## 3x4

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=5000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
    )
# Out:
# [upd 1/1000] train MSE=2.247e-01  val MSE=1.923e-01
# [upd 100/1000] train MSE=3.630e-03  val MSE=3.682e-03
# [upd 200/1000] train MSE=2.246e-03  val MSE=2.095e-03
# [upd 300/1000] train MSE=1.469e-03  val MSE=1.284e-03
# [upd 400/1000] train MSE=1.121e-03  val MSE=1.155e-03
# [upd 500/1000] train MSE=8.347e-04  val MSE=6.774e-04
# [upd 600/1000] train MSE=5.370e-04  val MSE=5.286e-04
# [upd 700/1000] train MSE=4.408e-04  val MSE=3.895e-04
# [upd 800/1000] train MSE=3.373e-04  val MSE=3.360e-04
# [upd 900/1000] train MSE=3.623e-04  val MSE=4.131e-04
# [upd 1000/1000] train MSE=2.805e-04  val MSE=3.328e-04
# Test results → MSE = 3.746e-04   R² = 0.9930

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=10000,
        n_updates=500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
    )
# Out:
# [upd 1/500] train MSE=2.297e-01  val MSE=1.927e-01
# [upd 50/500] train MSE=6.875e-03  val MSE=7.183e-03
# [upd 100/500] train MSE=3.266e-03  val MSE=3.421e-03
# [upd 150/500] train MSE=3.477e-03  val MSE=2.750e-03
# [upd 200/500] train MSE=1.865e-03  val MSE=1.932e-03
# [upd 250/500] train MSE=1.739e-03  val MSE=1.941e-03
# [upd 300/500] train MSE=1.178e-03  val MSE=1.159e-03
# [upd 350/500] train MSE=9.068e-04  val MSE=1.066e-03
# [upd 400/500] train MSE=1.119e-03  val MSE=1.389e-03
# [upd 450/500] train MSE=7.005e-04  val MSE=7.955e-04
# [upd 500/500] train MSE=7.487e-04  val MSE=7.620e-04
# Test results → MSE = 8.635e-04   R² = 0.9840

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=20000,
        n_updates=250,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/250] train MSE=2.282e-01  val MSE=1.927e-01
# [upd 25/250] train MSE=2.052e-02  val MSE=1.877e-02
# [upd 50/250] train MSE=7.409e-03  val MSE=6.979e-03
# [upd 75/250] train MSE=4.409e-03  val MSE=4.239e-03
# [upd 100/250] train MSE=3.137e-03  val MSE=3.338e-03
# [upd 125/250] train MSE=3.064e-03  val MSE=2.873e-03
# [upd 150/250] train MSE=2.278e-03  val MSE=2.289e-03
# [upd 175/250] train MSE=2.156e-03  val MSE=2.391e-03
# [upd 200/250] train MSE=1.804e-03  val MSE=1.802e-03
# [upd 225/250] train MSE=1.616e-03  val MSE=1.570e-03
# [upd 250/250] train MSE=1.501e-03  val MSE=1.627e-03
# Test results → MSE = 1.695e-03   R² = 0.9685

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=50000,
        n_updates=100,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/100] train MSE=2.280e-01  val MSE=1.927e-01
# [upd 10/100] train MSE=4.304e-02  val MSE=4.337e-02
# [upd 20/100] train MSE=2.545e-02  val MSE=2.477e-02
# [upd 30/100] train MSE=1.447e-02  val MSE=1.450e-02
# [upd 40/100] train MSE=1.028e-02  val MSE=9.794e-03
# [upd 50/100] train MSE=7.322e-03  val MSE=6.921e-03
# [upd 60/100] train MSE=5.466e-03  val MSE=5.497e-03
# [upd 70/100] train MSE=4.650e-03  val MSE=4.653e-03
# [upd 80/100] train MSE=4.097e-03  val MSE=4.079e-03
# [upd 90/100] train MSE=3.719e-03  val MSE=3.765e-03
# [upd 100/100] train MSE=3.336e-03  val MSE=3.458e-03
# Test results → MSE = 3.632e-03   R² = 0.9325

# %% [markdown]
# ## 5x 2.5

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=5000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/1000] train MSE=5.757e-02  val MSE=1.583e-01
# [upd 100/1000] train MSE=3.072e-03  val MSE=2.795e-03
# [upd 200/1000] train MSE=1.461e-03  val MSE=1.556e-03
# [upd 300/1000] train MSE=1.045e-03  val MSE=1.427e-03
# [upd 400/1000] train MSE=5.073e-04  val MSE=5.804e-04
# [upd 500/1000] train MSE=5.541e-04  val MSE=4.236e-04
# [upd 600/1000] train MSE=3.473e-04  val MSE=3.445e-04
# [upd 700/1000] train MSE=3.826e-04  val MSE=4.243e-04
# [upd 800/1000] train MSE=2.496e-04  val MSE=2.438e-04
# [upd 900/1000] train MSE=4.696e-04  val MSE=7.050e-04
# [upd 1000/1000] train MSE=3.985e-04  val MSE=2.302e-04
# Test results → MSE = 2.450e-04   R² = 0.9955

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=10000,
        n_updates=500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/500] train MSE=5.859e-02  val MSE=1.587e-01
# [upd 50/500] train MSE=5.246e-03  val MSE=4.943e-03
# [upd 100/500] train MSE=6.654e-03  val MSE=3.855e-03
# [upd 150/500] train MSE=1.714e-03  val MSE=1.770e-03
# [upd 200/500] train MSE=1.143e-03  val MSE=1.298e-03
# [upd 250/500] train MSE=9.571e-04  val MSE=8.979e-04
# [upd 300/500] train MSE=7.330e-04  val MSE=8.722e-04
# [upd 350/500] train MSE=6.085e-04  val MSE=5.647e-04
# [upd 400/500] train MSE=4.905e-04  val MSE=5.614e-04
# [upd 450/500] train MSE=4.254e-04  val MSE=4.393e-04
# [upd 500/500] train MSE=5.860e-04  val MSE=7.002e-04
# Test results → MSE = 7.715e-04   R² = 0.9857

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=20000,
        n_updates=250,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/250] train MSE=5.989e-02  val MSE=1.578e-01
# [upd 25/250] train MSE=1.122e-02  val MSE=1.221e-02
# [upd 50/250] train MSE=5.041e-03  val MSE=4.938e-03
# [upd 75/250] train MSE=5.092e-03  val MSE=3.908e-03
# [upd 100/250] train MSE=2.699e-03  val MSE=2.826e-03
# [upd 125/250] train MSE=4.837e-03  val MSE=5.073e-03
# [upd 150/250] train MSE=1.930e-03  val MSE=2.349e-03
# [upd 175/250] train MSE=1.564e-03  val MSE=1.522e-03
# [upd 200/250] train MSE=1.277e-03  val MSE=1.272e-03
# [upd 225/250] train MSE=1.172e-03  val MSE=1.209e-03
# [upd 250/250] train MSE=9.097e-04  val MSE=9.344e-04
# Test results → MSE = 1.019e-03   R² = 0.9811

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=50000,
        n_updates=100,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/100] train MSE=5.998e-02  val MSE=1.579e-01
# [upd 10/100] train MSE=3.558e-02  val MSE=2.964e-02
# [upd 20/100] train MSE=1.527e-02  val MSE=1.440e-02
# [upd 30/100] train MSE=9.192e-03  val MSE=9.577e-03
# [upd 40/100] train MSE=6.682e-03  val MSE=6.529e-03
# [upd 50/100] train MSE=5.015e-03  val MSE=5.209e-03
# [upd 60/100] train MSE=4.162e-03  val MSE=4.287e-03
# [upd 70/100] train MSE=3.480e-03  val MSE=3.553e-03
# [upd 80/100] train MSE=3.832e-03  val MSE=3.377e-03
# [upd 90/100] train MSE=2.710e-03  val MSE=2.928e-03
# [upd 100/100] train MSE=2.890e-03  val MSE=2.890e-03
# Test results → MSE = 3.128e-03   R² = 0.9419

# %% [markdown]
# ## 6x2

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=5000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10    
    )
# Out:
# [upd 1/1000] train MSE=9.622e-02  val MSE=6.880e-02
# [upd 100/1000] train MSE=3.209e-03  val MSE=2.854e-03
# [upd 200/1000] train MSE=1.334e-03  val MSE=1.340e-03
# [upd 300/1000] train MSE=9.237e-04  val MSE=8.663e-04
# [upd 400/1000] train MSE=5.849e-04  val MSE=6.439e-04
# [upd 500/1000] train MSE=4.960e-04  val MSE=5.789e-04
# [upd 600/1000] train MSE=5.170e-04  val MSE=3.564e-04
# [upd 700/1000] train MSE=3.303e-04  val MSE=3.099e-04
# [upd 800/1000] train MSE=2.326e-04  val MSE=2.475e-04
# [upd 900/1000] train MSE=9.137e-04  val MSE=5.455e-04
# [upd 1000/1000] train MSE=2.485e-04  val MSE=2.734e-04
# Test results → MSE = 2.808e-04   R² = 0.9948

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=10000,
        n_updates=500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/500] train MSE=9.731e-02  val MSE=6.836e-02
# [upd 50/500] train MSE=4.756e-03  val MSE=4.525e-03
# [upd 100/500] train MSE=2.606e-03  val MSE=3.098e-03
# [upd 150/500] train MSE=2.164e-03  val MSE=2.387e-03
# [upd 200/500] train MSE=1.275e-03  val MSE=1.365e-03
# [upd 250/500] train MSE=1.465e-03  val MSE=1.812e-03
# [upd 300/500] train MSE=8.566e-04  val MSE=1.106e-03
# [upd 350/500] train MSE=6.417e-04  val MSE=6.778e-04
# [upd 400/500] train MSE=6.776e-04  val MSE=6.787e-04
# [upd 450/500] train MSE=8.678e-04  val MSE=8.519e-04
# [upd 500/500] train MSE=5.476e-04  val MSE=6.139e-04
# Test results → MSE = 6.610e-04   R² = 0.9877

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=20000,
        n_updates=250,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/250] train MSE=9.605e-02  val MSE=6.880e-02
# [upd 50/250] train MSE=4.757e-03  val MSE=4.559e-03
# [upd 100/250] train MSE=3.147e-03  val MSE=3.207e-03
# [upd 150/250] train MSE=1.874e-03  val MSE=1.818e-03
# [upd 200/250] train MSE=1.869e-03  val MSE=1.322e-03
# [upd 250/250] train MSE=1.244e-03  val MSE=1.316e-03
# Test results → MSE = 1.414e-03   R² = 0.9737

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=50000,
        n_updates=100,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False  
    )
# Out:
# [upd 1/100] train MSE=9.345e-02  val MSE=6.865e-02
# [upd 10/100] train MSE=2.390e-02  val MSE=2.221e-02
# [upd 20/100] train MSE=1.077e-02  val MSE=1.119e-02
# [upd 30/100] train MSE=7.524e-03  val MSE=6.615e-03
# [upd 40/100] train MSE=5.341e-03  val MSE=5.103e-03
# [upd 50/100] train MSE=4.340e-03  val MSE=4.290e-03
# [upd 60/100] train MSE=3.990e-03  val MSE=3.775e-03
# [upd 70/100] train MSE=3.623e-03  val MSE=3.464e-03
# [upd 80/100] train MSE=3.340e-03  val MSE=3.490e-03
# [upd 90/100] train MSE=2.772e-03  val MSE=2.836e-03
# [upd 100/100] train MSE=5.201e-03  val MSE=4.387e-03
# Test results → MSE = 4.481e-03   R² = 0.9168

# %% [markdown]
# # Medium Testing Model (10 Epochs)

# %% [markdown]
# ## 3x4

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=5000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/10000] train MSE=2.247e-01  val MSE=1.923e-01
# [upd 1000/10000] train MSE=2.957e-04  val MSE=2.672e-04
# [upd 2000/10000] train MSE=1.873e-04  val MSE=1.869e-04
# [upd 3000/10000] train MSE=9.707e-05  val MSE=1.125e-04
# [upd 4000/10000] train MSE=8.602e-05  val MSE=8.601e-05
# [upd 5000/10000] train MSE=1.012e-04  val MSE=1.134e-04
# [upd 6000/10000] train MSE=6.702e-05  val MSE=6.305e-05
# [upd 7000/10000] train MSE=1.185e-04  val MSE=1.021e-04
# [upd 8000/10000] train MSE=4.354e-05  val MSE=4.596e-05
# [upd 9000/10000] train MSE=6.136e-05  val MSE=6.806e-05
# [upd 10000/10000] train MSE=6.719e-05  val MSE=4.265e-05
# Test results → MSE = 4.464e-05   R² = 0.9992

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=10000,
        n_updates=5000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/5000] train MSE=2.297e-01  val MSE=1.927e-01
# [upd 500/5000] train MSE=7.225e-04  val MSE=8.077e-04
# [upd 1000/5000] train MSE=3.576e-04  val MSE=6.742e-04
# [upd 1500/5000] train MSE=1.579e-04  val MSE=1.811e-04
# [upd 2000/5000] train MSE=2.289e-04  val MSE=3.036e-04
# [upd 2500/5000] train MSE=1.046e-04  val MSE=1.053e-04
# [upd 3000/5000] train MSE=9.295e-05  val MSE=8.942e-05
# [upd 3500/5000] train MSE=1.059e-04  val MSE=1.535e-04
# [upd 4000/5000] train MSE=1.139e-04  val MSE=1.245e-04
# [upd 4500/5000] train MSE=7.773e-05  val MSE=1.033e-04
# [upd 5000/5000] train MSE=8.728e-05  val MSE=7.882e-05
# Test results → MSE = 8.447e-05   R² = 0.9984

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=20000,
        n_updates=2500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/2500] train MSE=2.282e-01  val MSE=1.927e-01
# [upd 250/2500] train MSE=1.290e-03  val MSE=1.427e-03
# [upd 500/2500] train MSE=5.604e-04  val MSE=5.662e-04
# [upd 750/2500] train MSE=3.359e-04  val MSE=4.227e-04
# [upd 1000/2500] train MSE=2.967e-04  val MSE=3.148e-04
# [upd 1250/2500] train MSE=1.927e-04  val MSE=1.963e-04
# [upd 1500/2500] train MSE=1.638e-04  val MSE=1.634e-04
# [upd 1750/2500] train MSE=1.286e-04  val MSE=1.292e-04
# [upd 2000/2500] train MSE=1.169e-04  val MSE=1.165e-04
# [upd 2250/2500] train MSE=1.142e-04  val MSE=1.065e-04
# [upd 2500/2500] train MSE=8.868e-05  val MSE=9.656e-05
# Test results → MSE = 9.883e-05   R² = 0.9982

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=50000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/1000] train MSE=2.280e-01  val MSE=1.927e-01
# [upd 100/1000] train MSE=3.432e-03  val MSE=3.441e-03
# [upd 200/1000] train MSE=1.783e-03  val MSE=1.821e-03
# [upd 300/1000] train MSE=1.024e-03  val MSE=1.042e-03
# [upd 400/1000] train MSE=7.176e-04  val MSE=8.037e-04
# [upd 500/1000] train MSE=4.979e-04  val MSE=4.901e-04
# [upd 600/1000] train MSE=6.662e-04  val MSE=5.665e-04
# [upd 700/1000] train MSE=3.223e-04  val MSE=3.236e-04
# [upd 800/1000] train MSE=2.981e-04  val MSE=3.314e-04
# [upd 900/1000] train MSE=2.513e-04  val MSE=2.529e-04
# [upd 1000/1000] train MSE=2.534e-04  val MSE=2.995e-04
# Test results → MSE = 3.374e-04   R² = 0.9937

# %% [markdown]
# ## 5x 2.5

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=5000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/10000] train MSE=5.757e-02  val MSE=1.583e-01
# [upd 1000/10000] train MSE=2.010e-04  val MSE=2.067e-04
# [upd 2000/10000] train MSE=1.565e-04  val MSE=1.486e-04
# [upd 3000/10000] train MSE=1.123e-04  val MSE=1.322e-04
# [upd 4000/10000] train MSE=7.300e-05  val MSE=7.459e-05
# [upd 5000/10000] train MSE=1.295e-04  val MSE=1.236e-04
# [upd 6000/10000] train MSE=6.831e-05  val MSE=7.034e-05
# [upd 7000/10000] train MSE=7.670e-05  val MSE=7.815e-05
# [upd 8000/10000] train MSE=9.059e-05  val MSE=7.556e-05
# [upd 9000/10000] train MSE=1.194e-04  val MSE=8.467e-05
# [upd 10000/10000] train MSE=3.575e-05  val MSE=3.749e-05
# Test results → MSE = 4.056e-05   R² = 0.9992

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=10000,
        n_updates=5000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/5000] train MSE=5.859e-02  val MSE=1.587e-01
# [upd 500/5000] train MSE=3.431e-04  val MSE=3.611e-04
# [upd 1000/5000] train MSE=1.800e-04  val MSE=1.743e-04
# [upd 1500/5000] train MSE=1.615e-04  val MSE=1.554e-04
# [upd 2000/5000] train MSE=1.115e-04  val MSE=1.186e-04
# [upd 2500/5000] train MSE=8.051e-05  val MSE=9.148e-05
# [upd 3000/5000] train MSE=1.266e-04  val MSE=1.296e-04
# [upd 3500/5000] train MSE=6.763e-05  val MSE=6.753e-05
# [upd 4000/5000] train MSE=6.771e-05  val MSE=6.212e-05
# [upd 4500/5000] train MSE=8.712e-05  val MSE=7.601e-05
# [upd 5000/5000] train MSE=1.558e-04  val MSE=7.751e-05
# Test results → MSE = 7.471e-05   R² = 0.9986

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=20000,
        n_updates=2500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/2500] train MSE=5.989e-02  val MSE=1.578e-01
# [upd 250/2500] train MSE=1.162e-03  val MSE=1.017e-03
# [upd 500/2500] train MSE=3.530e-04  val MSE=3.562e-04
# [upd 750/2500] train MSE=2.178e-04  val MSE=2.434e-04
# [upd 1000/2500] train MSE=2.090e-04  val MSE=2.191e-04
# [upd 1250/2500] train MSE=1.501e-04  val MSE=1.644e-04
# [upd 1500/2500] train MSE=1.268e-04  val MSE=1.294e-04
# [upd 1750/2500] train MSE=1.240e-04  val MSE=1.260e-04
# [upd 2000/2500] train MSE=9.293e-05  val MSE=1.071e-04
# [upd 2250/2500] train MSE=1.420e-04  val MSE=1.515e-04
# [upd 2500/2500] train MSE=1.150e-04  val MSE=1.077e-04
# Test results → MSE = 1.071e-04   R² = 0.9980

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=50000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/1000] train MSE=5.998e-02  val MSE=1.579e-01
# [upd 100/1000] train MSE=3.693e-03  val MSE=3.304e-03
# [upd 200/1000] train MSE=1.288e-03  val MSE=1.309e-03
# [upd 300/1000] train MSE=7.080e-04  val MSE=7.070e-04
# [upd 400/1000] train MSE=5.020e-04  val MSE=5.080e-04
# [upd 500/1000] train MSE=3.755e-04  val MSE=3.969e-04
# [upd 600/1000] train MSE=1.224e-03  val MSE=1.381e-03
# [upd 700/1000] train MSE=4.424e-04  val MSE=4.234e-04
# [upd 800/1000] train MSE=2.010e-04  val MSE=2.497e-04
# [upd 900/1000] train MSE=2.125e-04  val MSE=2.648e-04
# [upd 1000/1000] train MSE=2.622e-04  val MSE=2.232e-04
# Test results → MSE = 2.323e-04   R² = 0.9957

# %% [markdown]
# ## 6x2

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=5000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/10000] train MSE=9.622e-02  val MSE=6.880e-02
# [upd 1000/10000] train MSE=2.485e-04  val MSE=2.734e-04
# [upd 2000/10000] train MSE=1.462e-04  val MSE=1.606e-04
# [upd 3000/10000] train MSE=1.406e-04  val MSE=1.272e-04
# [upd 4000/10000] train MSE=7.494e-05  val MSE=7.192e-05
# [upd 5000/10000] train MSE=5.763e-05  val MSE=5.849e-05
# [upd 6000/10000] train MSE=1.051e-04  val MSE=1.827e-04
# [upd 7000/10000] train MSE=4.501e-05  val MSE=6.260e-05
# [upd 8000/10000] train MSE=4.926e-05  val MSE=6.173e-05
# [upd 9000/10000] train MSE=5.413e-05  val MSE=1.337e-04
# [upd 10000/10000] train MSE=3.263e-05  val MSE=3.581e-05
# Test results → MSE = 3.710e-05   R² = 0.9993

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=10000,
        n_updates=5000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/5000] train MSE=9.731e-02  val MSE=6.836e-02
# [upd 500/5000] train MSE=5.476e-04  val MSE=6.139e-04
# [upd 1000/5000] train MSE=1.913e-04  val MSE=2.111e-04
# [upd 1500/5000] train MSE=1.501e-04  val MSE=1.755e-04
# [upd 2000/5000] train MSE=1.470e-04  val MSE=1.284e-04
# [upd 2500/5000] train MSE=1.228e-04  val MSE=1.612e-04
# [upd 3000/5000] train MSE=8.553e-05  val MSE=9.211e-05
# [upd 3500/5000] train MSE=1.557e-04  val MSE=1.377e-04
# [upd 4000/5000] train MSE=1.370e-04  val MSE=1.767e-04
# [upd 4500/5000] train MSE=3.124e-04  val MSE=3.144e-04
# [upd 5000/5000] train MSE=8.336e-05  val MSE=7.963e-05
# Test results → MSE = 8.872e-05   R² = 0.9984

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=20000,
        n_updates=2500,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/2500] train MSE=9.605e-02  val MSE=6.880e-02
# [upd 250/2500] train MSE=1.244e-03  val MSE=1.316e-03
# [upd 500/2500] train MSE=4.943e-04  val MSE=5.985e-04
# [upd 750/2500] train MSE=3.657e-04  val MSE=3.882e-04
# [upd 1000/2500] train MSE=2.007e-04  val MSE=2.338e-04
# [upd 1250/2500] train MSE=2.522e-04  val MSE=2.734e-04
# [upd 1500/2500] train MSE=2.120e-04  val MSE=2.278e-04
# [upd 1750/2500] train MSE=1.357e-04  val MSE=1.852e-04
# [upd 2000/2500] train MSE=1.561e-04  val MSE=1.260e-04
# [upd 2250/2500] train MSE=2.798e-04  val MSE=2.867e-04
# [upd 2500/2500] train MSE=8.481e-05  val MSE=9.393e-05
# Test results → MSE = 1.023e-04   R² = 0.9981

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=50000,
        n_updates=1000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=10  
    )
# Out:
# [upd 1/1000] train MSE=9.345e-02  val MSE=6.865e-02
# [upd 100/1000] train MSE=5.070e-03  val MSE=4.403e-03
# [upd 200/1000] train MSE=1.401e-03  val MSE=1.341e-03
# [upd 300/1000] train MSE=8.555e-04  val MSE=9.179e-04
# [upd 400/1000] train MSE=5.135e-04  val MSE=4.784e-04
# [upd 500/1000] train MSE=3.347e-04  val MSE=3.491e-04
# [upd 600/1000] train MSE=3.332e-04  val MSE=3.367e-04
# [upd 700/1000] train MSE=4.528e-04  val MSE=4.907e-04
# [upd 800/1000] train MSE=2.179e-04  val MSE=2.584e-04
# [upd 900/1000] train MSE=1.775e-04  val MSE=1.813e-04
# [upd 1000/1000] train MSE=1.689e-04  val MSE=1.667e-04
# Test results → MSE = 1.919e-04   R² = 0.9964

# %% [markdown]
# # Large Testing Model (100 Epochs)

# %% [markdown]
# ## 3x4

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=5000,
        n_updates=100000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/100000] train MSE=2.247e-01  val MSE=1.923e-01
# [upd 10000/100000] train MSE=2.938e-05  val MSE=3.259e-05
# [upd 20000/100000] train MSE=5.946e-05  val MSE=1.002e-04
# [upd 30000/100000] train MSE=1.673e-05  val MSE=1.629e-05
# [upd 40000/100000] train MSE=1.088e-05  val MSE=1.836e-05
# [upd 50000/100000] train MSE=1.015e-05  val MSE=1.273e-05
# [upd 60000/100000] train MSE=9.273e-06  val MSE=1.284e-05
# [upd 70000/100000] train MSE=9.295e-06  val MSE=9.396e-06
# [upd 80000/100000] train MSE=1.428e-05  val MSE=1.394e-05
# [upd 90000/100000] train MSE=8.343e-06  val MSE=7.852e-06
# [upd 100000/100000] train MSE=1.439e-05  val MSE=1.536e-05
# Test results → MSE = 1.400e-05   R² = 0.9997

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=10000,
        n_updates=50000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/50000] train MSE=2.297e-01  val MSE=1.927e-01
# [upd 5000/50000] train MSE=6.076e-05  val MSE=6.141e-05
# [upd 10000/50000] train MSE=4.704e-05  val MSE=5.714e-05
# [upd 15000/50000] train MSE=5.046e-05  val MSE=4.269e-05
# [upd 20000/50000] train MSE=2.324e-05  val MSE=1.696e-05
# [upd 25000/50000] train MSE=1.619e-05  val MSE=1.465e-05
# [upd 30000/50000] train MSE=9.561e-06  val MSE=1.217e-05
# [upd 35000/50000] train MSE=2.952e-05  val MSE=3.168e-05
# [upd 40000/50000] train MSE=1.406e-05  val MSE=1.303e-05
# [upd 45000/50000] train MSE=1.084e-05  val MSE=1.103e-05
# [upd 50000/50000] train MSE=1.367e-05  val MSE=1.392e-05
# Test results → MSE = 1.462e-05   R² = 0.9997

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=20000,
        n_updates=25000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/25000] train MSE=2.282e-01  val MSE=1.927e-01
# [upd 2500/25000] train MSE=2.553e-04  val MSE=1.200e-04
# [upd 5000/25000] train MSE=3.927e-04  val MSE=4.533e-04
# [upd 7500/25000] train MSE=6.662e-05  val MSE=4.342e-05
# [upd 10000/25000] train MSE=1.396e-04  val MSE=1.687e-04
# [upd 12500/25000] train MSE=1.772e-04  val MSE=1.622e-04
# [upd 15000/25000] train MSE=3.970e-05  val MSE=2.569e-05
# [upd 17500/25000] train MSE=2.396e-05  val MSE=2.749e-05
# [upd 20000/25000] train MSE=4.061e-05  val MSE=5.103e-05
# [upd 22500/25000] train MSE=1.748e-05  val MSE=1.964e-05
# [upd 25000/25000] train MSE=4.851e-05  val MSE=7.412e-05
# Test results → MSE = 7.687e-05   R² = 0.9986

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=300,
        layers=4,
        batch_size=50000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/10000] train MSE=2.280e-01  val MSE=1.927e-01
# [upd 1000/10000] train MSE=4.509e-04  val MSE=4.493e-04
# [upd 2000/10000] train MSE=1.216e-04  val MSE=1.465e-04
# [upd 3000/10000] train MSE=8.583e-05  val MSE=8.331e-05
# [upd 4000/10000] train MSE=6.688e-05  val MSE=6.386e-05
# [upd 5000/10000] train MSE=2.079e-04  val MSE=1.827e-04
# [upd 6000/10000] train MSE=4.807e-05  val MSE=5.306e-05
# [upd 7000/10000] train MSE=3.772e-05  val MSE=4.302e-05
# [upd 8000/10000] train MSE=3.441e-05  val MSE=3.481e-05
# [upd 9000/10000] train MSE=4.130e-05  val MSE=3.226e-05
# [upd 10000/10000] train MSE=3.028e-05  val MSE=3.041e-05
# Test results → MSE = 2.998e-05   R² = 0.9994

# %% [markdown]
# ## 5x 2.5

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=5000,
        n_updates=100000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=True,
        log_every=100  
    )
# Out:
# [upd 1/100000] train MSE=5.757e-02  val MSE=1.583e-01
# [upd 10000/100000] train MSE=3.605e-05  val MSE=3.491e-05
# [upd 20000/100000] train MSE=2.702e-05  val MSE=3.402e-05
# [upd 30000/100000] train MSE=1.485e-05  val MSE=1.855e-05
# [upd 40000/100000] train MSE=2.854e-05  val MSE=2.846e-05
# [upd 50000/100000] train MSE=2.583e-05  val MSE=3.157e-05
# [upd 60000/100000] train MSE=1.783e-05  val MSE=1.826e-05
# [upd 70000/100000] train MSE=2.313e-05  val MSE=2.270e-05
# [upd 80000/100000] train MSE=1.027e-05  val MSE=1.009e-05
# [upd 90000/100000] train MSE=1.084e-05  val MSE=1.076e-05
# [upd 100000/100000] train MSE=7.019e-06  val MSE=6.482e-06
# Test results → MSE = 5.937e-06   R² = 0.9999
# Saved model to model_w250_L5_bs5000_upd100000_Adam_lr0.001.pt

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=10000,
        n_updates=50000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/50000] train MSE=5.859e-02  val MSE=1.587e-01
# [upd 5000/50000] train MSE=4.602e-05  val MSE=4.963e-05
# [upd 10000/50000] train MSE=2.864e-05  val MSE=2.783e-05
# [upd 15000/50000] train MSE=2.666e-05  val MSE=3.431e-05
# [upd 20000/50000] train MSE=4.081e-05  val MSE=5.598e-05
# [upd 25000/50000] train MSE=2.827e-05  val MSE=3.329e-05
# [upd 30000/50000] train MSE=1.374e-05  val MSE=1.392e-05
# [upd 35000/50000] train MSE=1.421e-05  val MSE=1.186e-05
# [upd 40000/50000] train MSE=9.802e-06  val MSE=1.016e-05
# [upd 45000/50000] train MSE=9.467e-06  val MSE=1.014e-05
# [upd 50000/50000] train MSE=1.487e-05  val MSE=1.384e-05
# Test results → MSE = 1.324e-05   R² = 0.9998

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=20000,
        n_updates=25000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/25000] train MSE=5.989e-02  val MSE=1.578e-01
# [upd 2500/25000] train MSE=9.802e-05  val MSE=9.698e-05
# [upd 5000/25000] train MSE=1.545e-04  val MSE=1.637e-04
# [upd 7500/25000] train MSE=3.018e-05  val MSE=3.170e-05
# [upd 10000/25000] train MSE=3.266e-05  val MSE=3.038e-05
# [upd 12500/25000] train MSE=6.100e-05  val MSE=5.304e-05
# [upd 15000/25000] train MSE=1.893e-04  val MSE=1.444e-04
# [upd 17500/25000] train MSE=1.652e-05  val MSE=1.730e-05
# [upd 20000/25000] train MSE=4.267e-05  val MSE=4.103e-05
# [upd 22500/25000] train MSE=1.836e-05  val MSE=2.574e-05
# [upd 25000/25000] train MSE=1.284e-05  val MSE=1.325e-05
# Test results → MSE = 1.204e-05   R² = 0.9998

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=250,
        layers=5,
        batch_size=50000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/10000] train MSE=5.998e-02  val MSE=1.579e-01
# [upd 1000/10000] train MSE=2.028e-04  val MSE=2.600e-04
# [upd 2000/10000] train MSE=2.638e-04  val MSE=2.835e-04
# [upd 3000/10000] train MSE=6.252e-05  val MSE=6.356e-05
# [upd 4000/10000] train MSE=6.498e-05  val MSE=7.318e-05
# [upd 5000/10000] train MSE=4.371e-05  val MSE=4.598e-05
# [upd 6000/10000] train MSE=5.144e-05  val MSE=4.468e-05
# [upd 7000/10000] train MSE=4.934e-05  val MSE=6.327e-05
# [upd 8000/10000] train MSE=3.343e-05  val MSE=3.158e-05
# [upd 9000/10000] train MSE=4.422e-05  val MSE=5.273e-05
# [upd 10000/10000] train MSE=2.591e-05  val MSE=3.118e-05
# Test results → MSE = 2.851e-05   R² = 0.9995

# %% [markdown]
# ## 6x2

# %% [markdown]
# ### 5k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=5000,
        n_updates=100000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/100000] train MSE=9.622e-02  val MSE=6.880e-02
# [upd 10000/100000] train MSE=7.682e-05  val MSE=5.254e-05
# [upd 20000/100000] train MSE=3.320e-05  val MSE=2.688e-05
# [upd 30000/100000] train MSE=3.621e-05  val MSE=2.718e-05
# [upd 40000/100000] train MSE=1.123e-05  val MSE=1.265e-05
# [upd 50000/100000] train MSE=1.359e-05  val MSE=1.155e-05
# [upd 60000/100000] train MSE=1.735e-05  val MSE=1.855e-05
# [upd 70000/100000] train MSE=1.238e-05  val MSE=1.796e-05
# [upd 80000/100000] train MSE=1.850e-05  val MSE=2.943e-05
# [upd 90000/100000] train MSE=9.296e-06  val MSE=1.221e-05
# [upd 100000/100000] train MSE=8.335e-06  val MSE=9.403e-06
# Test results → MSE = 8.752e-06   R² = 0.9998

# %% [markdown]
# ### 10k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=10000,
        n_updates=50000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/50000] train MSE=9.731e-02  val MSE=6.836e-02
# [upd 5000/50000] train MSE=1.408e-04  val MSE=1.198e-04
# [upd 10000/50000] train MSE=1.144e-04  val MSE=1.391e-04
# [upd 15000/50000] train MSE=4.865e-05  val MSE=3.426e-05
# [upd 20000/50000] train MSE=1.959e-05  val MSE=2.192e-05
# [upd 25000/50000] train MSE=2.934e-05  val MSE=4.434e-05
# [upd 30000/50000] train MSE=2.788e-05  val MSE=2.063e-05
# [upd 35000/50000] train MSE=1.203e-05  val MSE=1.299e-05
# [upd 40000/50000] train MSE=2.112e-05  val MSE=2.143e-05
# [upd 45000/50000] train MSE=1.185e-05  val MSE=1.182e-05
# [upd 50000/50000] train MSE=1.535e-05  val MSE=1.858e-05
# Test results → MSE = 1.947e-05   R² = 0.9996

# %% [markdown]
# ### 20k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=20000,
        n_updates=25000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/25000] train MSE=9.605e-02  val MSE=6.880e-02
# [upd 2500/25000] train MSE=3.292e-04  val MSE=5.758e-04
# [upd 5000/25000] train MSE=5.180e-05  val MSE=5.705e-05
# [upd 7500/25000] train MSE=3.789e-05  val MSE=4.108e-05
# [upd 10000/25000] train MSE=6.409e-05  val MSE=9.158e-05
# [upd 12500/25000] train MSE=3.770e-05  val MSE=4.267e-05
# [upd 15000/25000] train MSE=2.028e-05  val MSE=2.157e-05
# [upd 17500/25000] train MSE=1.771e-04  val MSE=1.202e-04
# [upd 20000/25000] train MSE=1.171e-04  val MSE=6.296e-05
# [upd 22500/25000] train MSE=1.547e-05  val MSE=1.789e-05
# [upd 25000/25000] train MSE=2.285e-05  val MSE=4.856e-05
# Test results → MSE = 4.709e-05   R² = 0.9991

# %% [markdown]
# ### 50k

# %%
run_experiment_updates_per_update(
        width=200,
        layers=6,
        batch_size=50000,
        n_updates=10000,
        lr=1e-3,
        optimizer_name="Adam",
        seed=42,
        save_model=False,
        log_every=100  
    )
# Out:
# [upd 1/10000] train MSE=9.345e-02  val MSE=6.865e-02
# [upd 1000/10000] train MSE=1.730e-04  val MSE=1.681e-04
# [upd 2000/10000] train MSE=1.233e-04  val MSE=1.267e-04
# [upd 3000/10000] train MSE=2.699e-04  val MSE=2.494e-04
# [upd 4000/10000] train MSE=7.764e-05  val MSE=7.698e-05
# [upd 5000/10000] train MSE=9.050e-05  val MSE=1.126e-04
# [upd 6000/10000] train MSE=7.703e-05  val MSE=7.285e-05
# [upd 7000/10000] train MSE=8.349e-05  val MSE=9.338e-05
# [upd 8000/10000] train MSE=3.232e-05  val MSE=3.451e-05
# [upd 9000/10000] train MSE=3.285e-05  val MSE=4.352e-05
# [upd 10000/10000] train MSE=1.139e-04  val MSE=8.348e-05
# Test results → MSE = 7.981e-05   R² = 0.9985

# %% [markdown]
# # Neural Net + Delta and Vega

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# 1) Device & seeds
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on:", DEVICE)
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# 2) Load dataset with price and FD Greeks
df = pd.read_parquet("Train_clean_5m_fd_greeks.parquet", engine="pyarrow")

# 3) Define target and feature columns
target_cols = ["price/k"] + [f"delta_{i}" for i in range(3)] + [f"vega_{i}" for i in range(3)]
feature_cols = [c for c in df.columns if c not in target_cols]

# 4) Extract NumPy arrays
X = df[feature_cols].values.astype(np.float32)
y = df[target_cols].values.astype(np.float32)

# 5) Train/val split (99/1)
X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.01, random_state=42)

# 6) Separate price, delta, vega targets
price_tr, delta_tr, vega_tr = y_tr[:,0], y_tr[:,1:4], y_tr[:,4:7]
price_val, delta_val, vega_val = y_val[:,0], y_val[:,1:4], y_val[:,4:7]

# 7) Build PyTorch datasets
train_ds = TensorDataset(
    torch.from_numpy(X_tr),
    torch.from_numpy(price_tr),
    torch.from_numpy(delta_tr),
    torch.from_numpy(vega_tr)
)
val_ds = TensorDataset(
    torch.from_numpy(X_val),
    torch.from_numpy(price_val),
    torch.from_numpy(delta_val),
    torch.from_numpy(vega_val)
)
print(f"train {len(train_ds):,} rows")
print(f"valid {len(val_ds):,} rows")

# 8) Define single-output BasketNet model
class BasketNet(nn.Module):
    def __init__(self, in_dim, width=300, layers=4):
        super().__init__()
        blocks = [nn.Linear(in_dim, width), nn.ReLU()]
        for _ in range(layers-1):
            blocks += [nn.Linear(width, width), nn.ReLU()]
        blocks.append(nn.Linear(width, 1))
        self.net = nn.Sequential(*blocks)
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        return self.net(x).squeeze(1)  # (batch,)

# 9) Feature indices for Greeks
delta_idx = [feature_cols.index(f"S0_{i}/K") for i in range(3)]
vega_idx  = [feature_cols.index(f"sigma_{i}") for i in range(3)]

# 10) Training loop with Sobolev (differential) loss
def run_differential(
    width=300,
    layers=4,
    batch_size=50_000,
    n_updates=100_000,
    lr=1e-3,
    λ=1.0,
    log_every=5_000
):
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False, pin_memory=True)

    model     = BasketNet(len(feature_cols), width, layers).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()

    train_losses, valid_losses, steps = [], [], []

    # infinite iterator for training
    def inf_iter(loader):
        while True:
            for batch in loader:
                yield batch
    train_iter = inf_iter(train_loader)

    model.train()
    for step in range(1, n_updates+1):
        Xb, p_true, d_true, v_true = next(train_iter)
        Xb = Xb.to(DEVICE).requires_grad_(True)
        p_true, d_true, v_true = [t.to(DEVICE) for t in (p_true, d_true, v_true)]

        optimizer.zero_grad()

        # forward price
        p_pred = model(Xb)
        loss_p = criterion(p_pred, p_true)

        # compute autograd Greeks (retain graph for Sobolev loss)
        grad = torch.autograd.grad(
            outputs=p_pred,
            inputs=Xb,
            grad_outputs=torch.ones_like(p_pred),
            create_graph=True
        )[0]
        # extract predictions
        d_pred = grad[:, delta_idx]
        v_pred = grad[:, vega_idx]
        loss_g = criterion(d_pred, d_true) + criterion(v_pred, v_true)

        # total loss
        loss = loss_p + λ * loss_g
        loss.backward()
        optimizer.step()

        # validation & logging
        if step == 1 or step % log_every == 0 or step == n_updates:
            model.eval()
            tot_val, cnt = 0.0, 0
            for Xv, pv, dv, vv in val_loader:
                Xv = Xv.to(DEVICE).requires_grad_(True)
                pv, dv, vv = [t.to(DEVICE) for t in (pv, dv, vv)]

                pp = model(Xv)
                lp = criterion(pp, pv)

                g = torch.autograd.grad(
                    outputs=pp,
                    inputs=Xv,
                    grad_outputs=torch.ones_like(pp),
                    create_graph=False
                )[0]
                lg = criterion(g[:, delta_idx], dv) + criterion(g[:, vega_idx], vv)

                tot_val += (lp + λ * lg).item() * Xv.size(0)
                cnt     += Xv.size(0)

            val_loss = tot_val / cnt
            train_losses.append(loss.item())
            valid_losses.append(val_loss)
            steps.append(step)
            print(f"[upd {step}/{n_updates}] train loss={loss.item():.3e}  val loss={val_loss:.3e}")
            model.train()

    # plot training curves
    plt.figure(figsize=(7,4))
    plt.plot(steps, np.log10(train_losses), label="train")
    plt.plot(steps, np.log10(valid_losses), label="valid")
    plt.xlabel("update step")
    plt.ylabel("log10 loss")
    plt.legend()
    plt.tight_layout()
    plt.show()

    return model

# 11) Run training
model = run_differential(
    width=250,
    layers=5,
    batch_size=5_000,
    n_updates=100_000,
    lr=1e-3,
    λ=1.0,
    log_every=5_000
)

# 12) Test evaluation
# load test data
test_df = pd.read_parquet("Test_clean_5k_aad_greeks.parquet", engine="pyarrow")
X_test = torch.from_numpy(test_df[feature_cols].values.astype(np.float32)).to(DEVICE).requires_grad_(True)
y_test = test_df[target_cols].values.astype(np.float32)

model.eval()
# forward pass
p_pred_tensor = model(X_test)
# compute AAD Greeks
grad_test = torch.autograd.grad(
    outputs=p_pred_tensor,
    inputs=X_test,
    grad_outputs=torch.ones_like(p_pred_tensor)
)[0]

# convert to numpy
price_pred = p_pred_tensor.detach().cpu().numpy()
delta_pred = grad_test[:, delta_idx].detach().cpu().numpy()
vega_pred  = grad_test[:, vega_idx].detach().cpu().numpy()

# true targets
p_true = y_test[:, 0]
d_true = y_test[:, 1:4]
v_true = y_test[:, 4:7]

# 13) Metrics & plots
def report_and_plot(name, pred, true):
    mae  = np.mean(np.abs(pred - true))
    rmse = np.sqrt(np.mean((pred - true)**2))
    r2   = np.corrcoef(pred, true)[0,1]**2
    print(f"{name:>8s}: MAE={mae:.3e}, RMSE={rmse:.3e}, R²={r2:.4f}")
    plt.figure(figsize=(4,4))
    plt.scatter(true, pred, s=3, alpha=0.3)
    lo, hi = min(true.min(), pred.min()), max(true.max(), pred.max())
    plt.plot([lo,hi],[lo,hi],'k--')
    plt.title(f"{name}: MAE={mae:.3e}, RMSE={rmse:.3e}, R²={r2:.4f}")
    plt.xlabel("True")
    plt.ylabel("Predicted")
    plt.grid(ls=":")
    plt.tight_layout()
    plt.show()

print("\nTest set performance:")
report_and_plot("Price", price_pred, p_true)
for i in range(3):
    report_and_plot(f"Delta_{i}", delta_pred[:, i], d_true[:, i])
for i in range(3):
    report_and_plot(f"Vega_{i}",  vega_pred[:, i], v_true[:, i])
# Out:
# Running on: cuda
# train 4,743,506 rows
# valid 47,915 rows
# c:\Users\jacks\anaconda3\envs\tf-gpu\lib\site-packages\torch\autograd\graph.py:824: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\cuda\CublasHandlePool.cpp:181.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [upd 1/100000] train loss=1.436e-01  val loss=2.315e-01
# [upd 5000/100000] train loss=1.861e-03  val loss=1.983e-03
# [upd 10000/100000] train loss=1.967e-03  val loss=2.243e-03
# [upd 15000/100000] train loss=1.290e-03  val loss=1.378e-03
# [upd 20000/100000] train loss=1.379e-03  val loss=1.422e-03
# [upd 25000/100000] train loss=1.329e-03  val loss=1.332e-03
# [upd 30000/100000] train loss=1.529e-03  val loss=1.445e-03
# [upd 35000/100000] train loss=1.458e-03  val loss=1.381e-03
# [upd 40000/100000] train loss=1.358e-03  val loss=1.370e-03
# [upd 45000/100000] train loss=1.453e-03  val loss=1.368e-03
# [upd 50000/100000] train loss=1.445e-03  val loss=1.276e-03
# [upd 55000/100000] train loss=1.259e-03  val loss=1.299e-03
# [upd 60000/100000] train loss=1.410e-03  val loss=1.467e-03
# [upd 65000/100000] train loss=1.175e-03  val loss=1.260e-03
# [upd 70000/100000] train loss=1.248e-03  val loss=1.271e-03
# [upd 75000/100000] train loss=1.433e-03  val loss=1.354e-03
# [upd 80000/100000] train loss=1.495e-03  val loss=1.352e-03
# [upd 85000/100000] train loss=1.092e-03  val loss=1.268e-03
# [upd 90000/100000] train loss=1.295e-03  val loss=1.334e-03
# [upd 95000/100000] train loss=1.272e-03  val loss=1.221e-03
# [upd 100000/100000] train loss=1.255e-03  val loss=1.292e-03
# Test set performance:
#    Price: MAE=4.459e-03, RMSE=7.344e-03, R²=0.9992
#  Delta_0: MAE=9.942e-03, RMSE=1.772e-02, R²=0.9916
#  Delta_1: MAE=9.907e-03, RMSE=1.829e-02, R²=0.9914
#  Delta_2: MAE=1.019e-02, RMSE=1.867e-02, R²=0.9907
#   Vega_0: MAE=1.787e-02, RMSE=3.371e-02, R²=0.9690
#   Vega_1: MAE=1.715e-02, RMSE=3.365e-02, R²=0.9655
#   Vega_2: MAE=1.705e-02, RMSE=3.014e-02, R²=0.9743

# %% [markdown]
# # Neural Net + Delta and Vega AAD

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# 1) Device & seeds
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on:", DEVICE)
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# 2) Load dataset with price and FD Greeks
df = pd.read_parquet("Train_clean_5m_aad_greeks.parquet", engine="pyarrow")

# 3) Define target and feature columns
target_cols = ["price/k"] + [f"delta_{i}" for i in range(3)] + [f"vega_{i}" for i in range(3)]
feature_cols = [c for c in df.columns if c not in target_cols]

# 4) Extract NumPy arrays
X = df[feature_cols].values.astype(np.float32)
y = df[target_cols].values.astype(np.float32)

# 5) Train/val split (99/1)
X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.01, random_state=42)

# 6) Separate price, delta, vega targets
price_tr, delta_tr, vega_tr = y_tr[:,0], y_tr[:,1:4], y_tr[:,4:7]
price_val, delta_val, vega_val = y_val[:,0], y_val[:,1:4], y_val[:,4:7]

# 7) Build PyTorch datasets
train_ds = TensorDataset(
    torch.from_numpy(X_tr),
    torch.from_numpy(price_tr),
    torch.from_numpy(delta_tr),
    torch.from_numpy(vega_tr)
)
val_ds = TensorDataset(
    torch.from_numpy(X_val),
    torch.from_numpy(price_val),
    torch.from_numpy(delta_val),
    torch.from_numpy(vega_val)
)
print(f"train {len(train_ds):,} rows")
print(f"valid {len(val_ds):,} rows")

# 8) Define single-output BasketNet model
class BasketNet(nn.Module):
    def __init__(self, in_dim, width=300, layers=4):
        super().__init__()
        blocks = [nn.Linear(in_dim, width), nn.ReLU()]
        for _ in range(layers-1):
            blocks += [nn.Linear(width, width), nn.ReLU()]
        blocks.append(nn.Linear(width, 1))
        self.net = nn.Sequential(*blocks)
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        return self.net(x).squeeze(1)  # (batch,)

# 9) Feature indices for Greeks
delta_idx = [feature_cols.index(f"S0_{i}/K") for i in range(3)]
vega_idx  = [feature_cols.index(f"sigma_{i}") for i in range(3)]

# 10) Training loop with Sobolev (differential) loss
def run_differential(
    width=300,
    layers=4,
    batch_size=50_000,
    n_updates=100_000,
    lr=1e-3,
    λ=1.0,
    log_every=5_000
):
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False, pin_memory=True)

    model     = BasketNet(len(feature_cols), width, layers).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()

    train_losses, valid_losses, steps = [], [], []

    # infinite iterator for training
    def inf_iter(loader):
        while True:
            for batch in loader:
                yield batch
    train_iter = inf_iter(train_loader)

    model.train()
    for step in range(1, n_updates+1):
        Xb, p_true, d_true, v_true = next(train_iter)
        Xb = Xb.to(DEVICE).requires_grad_(True)
        p_true, d_true, v_true = [t.to(DEVICE) for t in (p_true, d_true, v_true)]

        optimizer.zero_grad()

        # forward price
        p_pred = model(Xb)
        loss_p = criterion(p_pred, p_true)

        # compute autograd Greeks (retain graph for Sobolev loss)
        grad = torch.autograd.grad(
            outputs=p_pred,
            inputs=Xb,
            grad_outputs=torch.ones_like(p_pred),
            create_graph=True
        )[0]
        # extract predictions
        d_pred = grad[:, delta_idx]
        v_pred = grad[:, vega_idx]
        loss_g = criterion(d_pred, d_true) + criterion(v_pred, v_true)

        # total loss
        loss = loss_p + λ * loss_g
        loss.backward()
        optimizer.step()

        # validation & logging
        if step == 1 or step % log_every == 0 or step == n_updates:
            model.eval()
            tot_val, cnt = 0.0, 0
            for Xv, pv, dv, vv in val_loader:
                Xv = Xv.to(DEVICE).requires_grad_(True)
                pv, dv, vv = [t.to(DEVICE) for t in (pv, dv, vv)]

                pp = model(Xv)
                lp = criterion(pp, pv)

                g = torch.autograd.grad(
                    outputs=pp,
                    inputs=Xv,
                    grad_outputs=torch.ones_like(pp),
                    create_graph=False
                )[0]
                lg = criterion(g[:, delta_idx], dv) + criterion(g[:, vega_idx], vv)

                tot_val += (lp + λ * lg).item() * Xv.size(0)
                cnt     += Xv.size(0)

            val_loss = tot_val / cnt
            train_losses.append(loss.item())
            valid_losses.append(val_loss)
            steps.append(step)
            print(f"[upd {step}/{n_updates}] train loss={loss.item():.3e}  val loss={val_loss:.3e}")
            model.train()

    # plot training curves
    plt.figure(figsize=(7,4))
    plt.plot(steps, np.log10(train_losses), label="train")
    plt.plot(steps, np.log10(valid_losses), label="valid")
    plt.xlabel("update step")
    plt.ylabel("log10 loss")
    plt.legend()
    plt.tight_layout()
    plt.show()

    return model

# 11) Run training
model = run_differential(
    width=250,
    layers=5,
    batch_size=5_000,
    n_updates=100_000,
    lr=1e-3,
    λ=1.0,
    log_every=5_000
)

# 12) Test evaluation
# load test data
test_df = pd.read_parquet("Test_clean_5k_aad_greeks.parquet", engine="pyarrow")
X_test = torch.from_numpy(test_df[feature_cols].values.astype(np.float32)).to(DEVICE).requires_grad_(True)
y_test = test_df[target_cols].values.astype(np.float32)

model.eval()
# forward pass
p_pred_tensor = model(X_test)
# compute AAD Greeks
grad_test = torch.autograd.grad(
    outputs=p_pred_tensor,
    inputs=X_test,
    grad_outputs=torch.ones_like(p_pred_tensor)
)[0]

# convert to numpy
price_pred = p_pred_tensor.detach().cpu().numpy()
delta_pred = grad_test[:, delta_idx].detach().cpu().numpy()
vega_pred  = grad_test[:, vega_idx].detach().cpu().numpy()

# true targets
p_true = y_test[:, 0]
d_true = y_test[:, 1:4]
v_true = y_test[:, 4:7]

# 13) Metrics & plots
def report_and_plot(name, pred, true):
    mae  = np.mean(np.abs(pred - true))
    rmse = np.sqrt(np.mean((pred - true)**2))
    r2   = np.corrcoef(pred, true)[0,1]**2
    print(f"{name:>8s}: MAE={mae:.3e}, RMSE={rmse:.3e}, R²={r2:.4f}")
    plt.figure(figsize=(4,4))
    plt.scatter(true, pred, s=3, alpha=0.3)
    lo, hi = min(true.min(), pred.min()), max(true.max(), pred.max())
    plt.plot([lo,hi],[lo,hi],'k--')
    plt.title(f"{name}: MAE={mae:.3e}, RMSE={rmse:.3e}, R²={r2:.4f}")
    plt.xlabel("True")
    plt.ylabel("Predicted")
    plt.grid(ls=":")
    plt.tight_layout()
    plt.show()

print("\nTest set performance:")
report_and_plot("Price", price_pred, p_true)
for i in range(3):
    report_and_plot(f"Delta_{i}", delta_pred[:, i], d_true[:, i])
for i in range(3):
    report_and_plot(f"Vega_{i}",  vega_pred[:, i], v_true[:, i])
# Out:
# Running on: cuda
# train 4,743,506 rows
# valid 47,915 rows
# [upd 1/100000] train loss=1.436e-01  val loss=2.315e-01
# [upd 5000/100000] train loss=1.983e-03  val loss=2.006e-03
# [upd 10000/100000] train loss=2.082e-03  val loss=2.167e-03
# [upd 15000/100000] train loss=1.469e-03  val loss=1.529e-03
# [upd 20000/100000] train loss=1.326e-03  val loss=1.391e-03
# [upd 25000/100000] train loss=1.417e-03  val loss=1.312e-03
# [upd 30000/100000] train loss=1.639e-03  val loss=1.443e-03
# [upd 35000/100000] train loss=1.418e-03  val loss=1.341e-03
# [upd 40000/100000] train loss=1.410e-03  val loss=1.396e-03
# [upd 45000/100000] train loss=1.400e-03  val loss=1.336e-03
# [upd 50000/100000] train loss=1.443e-03  val loss=1.264e-03
# [upd 55000/100000] train loss=1.372e-03  val loss=1.376e-03
# [upd 60000/100000] train loss=1.307e-03  val loss=1.324e-03
# [upd 65000/100000] train loss=1.243e-03  val loss=1.425e-03
# [upd 70000/100000] train loss=1.236e-03  val loss=1.235e-03
# [upd 75000/100000] train loss=1.245e-03  val loss=1.217e-03
# [upd 80000/100000] train loss=1.373e-03  val loss=1.298e-03
# [upd 85000/100000] train loss=1.182e-03  val loss=1.370e-03
# [upd 90000/100000] train loss=1.300e-03  val loss=1.291e-03
# [upd 95000/100000] train loss=1.203e-03  val loss=1.336e-03
# [upd 100000/100000] train loss=1.325e-03  val loss=1.333e-03
# Test set performance:
#    Price: MAE=5.255e-03, RMSE=7.787e-03, R²=0.9993
#  Delta_0: MAE=9.957e-03, RMSE=1.726e-02, R²=0.9919
#  Delta_1: MAE=9.851e-03, RMSE=1.768e-02, R²=0.9919
#  Delta_2: MAE=9.838e-03, RMSE=1.742e-02, R²=0.9918
#   Vega_0: MAE=1.789e-02, RMSE=3.375e-02, R²=0.9689
#   Vega_1: MAE=1.712e-02, RMSE=3.237e-02, R²=0.9678
#   Vega_2: MAE=1.725e-02, RMSE=3.107e-02, R²=0.9725

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# 1) Device & seeds
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on:", DEVICE)
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# 2) Load dataset with price and FD Greeks
df = pd.read_parquet("Train_clean_5m_aad_greeks.parquet", engine="pyarrow")

# 3) Define target and feature columns
target_cols = ["price/k"] + [f"delta_{i}" for i in range(3)] + [f"vega_{i}" for i in range(3)]
feature_cols = [c for c in df.columns if c not in target_cols]

# 4) Extract NumPy arrays
X = df[feature_cols].values.astype(np.float32)
y = df[target_cols].values.astype(np.float32)

# 5) Train/val split (99/1)
X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.01, random_state=42)

# 6) Separate price, delta, vega targets
price_tr, delta_tr, vega_tr = y_tr[:,0], y_tr[:,1:4], y_tr[:,4:7]
price_val, delta_val, vega_val = y_val[:,0], y_val[:,1:4], y_val[:,4:7]

# 7) Build PyTorch datasets
train_ds = TensorDataset(
    torch.from_numpy(X_tr),
    torch.from_numpy(price_tr),
    torch.from_numpy(delta_tr),
    torch.from_numpy(vega_tr)
)
val_ds = TensorDataset(
    torch.from_numpy(X_val),
    torch.from_numpy(price_val),
    torch.from_numpy(delta_val),
    torch.from_numpy(vega_val)
)
print(f"train {len(train_ds):,} rows")
print(f"valid {len(val_ds):,} rows")

# 8) Define single-output BasketNet model with Softplus activations
class BasketNet(nn.Module):
    def __init__(self, in_dim, width=300, layers=4):
        super().__init__()
        blocks = [nn.Linear(in_dim, width), nn.Softplus()]
        for _ in range(layers - 1):
            blocks += [nn.Linear(width, width), nn.Softplus()]
        blocks.append(nn.Linear(width, 1))
        self.net = nn.Sequential(*blocks)
        # Xavier init for all Linear layers
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        # returns shape (batch,)
        return self.net(x).squeeze(1)

# 9) Feature indices for Greeks
delta_idx = [feature_cols.index(f"S0_{i}/K") for i in range(3)]
vega_idx  = [feature_cols.index(f"sigma_{i}") for i in range(3)]

# 10) Training loop with Sobolev (differential) loss
def run_differential(
    width=300,
    layers=4,
    batch_size=50_000,
    n_updates=100_000,
    lr=1e-3,
    λ=1.0,
    log_every=5_000
):
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False, pin_memory=True)

    model     = BasketNet(len(feature_cols), width, layers).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()

    train_losses, valid_losses, steps = [], [], []

    # infinite iterator for training
    def inf_iter(loader):
        while True:
            for batch in loader:
                yield batch
    train_iter = inf_iter(train_loader)

    model.train()
    for step in range(1, n_updates + 1):
        Xb, p_true, d_true, v_true = next(train_iter)
        Xb = Xb.to(DEVICE).requires_grad_(True)
        p_true, d_true, v_true = [t.to(DEVICE) for t in (p_true, d_true, v_true)]

        optimizer.zero_grad()

        # forward price
        p_pred = model(Xb)
        loss_p = criterion(p_pred, p_true)

        # compute autograd Greeks (retain graph for Sobolev loss)
        grad = torch.autograd.grad(
            outputs=p_pred,
            inputs=Xb,
            grad_outputs=torch.ones_like(p_pred),
            create_graph=True
        )[0]
        # extract predictions
        d_pred = grad[:, delta_idx]
        v_pred = grad[:, vega_idx]
        loss_g = criterion(d_pred, d_true) + criterion(v_pred, v_true)

        # total loss
        loss = loss_p + λ * loss_g
        loss.backward()
        optimizer.step()

        # validation & logging
        if step == 1 or step % log_every == 0 or step == n_updates:
            model.eval()
            tot_val, cnt = 0.0, 0
            for Xv, pv, dv, vv in val_loader:
                Xv = Xv.to(DEVICE).requires_grad_(True)
                pv, dv, vv = [t.to(DEVICE) for t in (pv, dv, vv)]

                pp = model(Xv)
                lp = criterion(pp, pv)

                g = torch.autograd.grad(
                    outputs=pp,
                    inputs=Xv,
                    grad_outputs=torch.ones_like(pp),
                    create_graph=False
                )[0]
                lg = criterion(g[:, delta_idx], dv) + criterion(g[:, vega_idx], vv)

                tot_val += (lp + λ * lg).item() * Xv.size(0)
                cnt     += Xv.size(0)

            val_loss = tot_val / cnt
            train_losses.append(loss.item())
            valid_losses.append(val_loss)
            steps.append(step)
            print(f"[upd {step}/{n_updates}] train loss={loss.item():.3e}  val loss={val_loss:.3e}")
            model.train()

    # plot training curves
    plt.figure(figsize=(7,4))
    plt.plot(steps, np.log10(train_losses), label="train")
    plt.plot(steps, np.log10(valid_losses), label="valid")
    plt.xlabel("update step")
    plt.ylabel("log10 loss")
    plt.legend()
    plt.tight_layout()
    plt.show()

    return model

# 11) Run training
model = run_differential(
    width=250,
    layers=5,
    batch_size=5_000,
    n_updates=100_000,
    lr=1e-3,
    λ=1.0,
    log_every=5_000
)

# 12) Test evaluation
test_df = pd.read_parquet("Test_clean_5k_aad_greeks.parquet", engine="pyarrow")
X_test = torch.from_numpy(test_df[feature_cols].values.astype(np.float32)).to(DEVICE).requires_grad_(True)
y_test = test_df[target_cols].values.astype(np.float32)

model.eval()
# forward pass
p_pred_tensor = model(X_test)
# compute AAD Greeks
grad_test = torch.autograd.grad(
    outputs=p_pred_tensor,
    inputs=X_test,
    grad_outputs=torch.ones_like(p_pred_tensor)
)[0]

# convert to numpy
price_pred = p_pred_tensor.detach().cpu().numpy()
delta_pred = grad_test[:, delta_idx].detach().cpu().numpy()
vega_pred  = grad_test[:, vega_idx].detach().cpu().numpy()

# true targets
p_true = y_test[:, 0]
d_true = y_test[:, 1:4]
v_true = y_test[:, 4:7]

# 13) Metrics & plots
def report_and_plot(name, pred, true):
    mae  = np.mean(np.abs(pred - true))
    rmse = np.sqrt(np.mean((pred - true)**2))
    r2   = np.corrcoef(pred, true)[0,1]**2
    print(f"{name:>8s}: MAE={mae:.3e}, RMSE={rmse:.3e}, R²={r2:.4f}")
    plt.figure(figsize=(4,4))
    plt.scatter(true, pred, s=3, alpha=0.3)
    lo, hi = min(true.min(), pred.min()), max(true.max(), pred.max())
    plt.plot([lo,hi],[lo,hi],'k--')
    plt.title(f"{name}: MAE={mae:.3e}, RMSE={rmse:.3e}, R²={r2:.4f}")
    plt.xlabel("True")
    plt.ylabel("Predicted")
    plt.grid(ls=":")
    plt.tight_layout()
    plt.show()

print("\nTest set performance:")
report_and_plot("Price", price_pred, p_true)
for i in range(3):
    report_and_plot(f"Delta_{i}", delta_pred[:, i], d_true[:, i])
for i in range(3):
    report_and_plot(f"Vega_{i}", vega_pred[:, i], v_true[:, i])
# Out:
# Running on: cuda
# train 4,743,506 rows
# valid 47,915 rows
# [upd 1/100000] train loss=9.298e-01  val loss=6.470e+00
# [upd 5000/100000] train loss=3.749e-02  val loss=3.728e-02
# [upd 10000/100000] train loss=1.488e-02  val loss=1.657e-02
# [upd 15000/100000] train loss=6.171e-03  val loss=6.326e-03
# [upd 20000/100000] train loss=1.647e-03  val loss=1.769e-03
# [upd 25000/100000] train loss=8.978e-04  val loss=8.234e-04
# [upd 30000/100000] train loss=6.526e-04  val loss=6.168e-04
# [upd 35000/100000] train loss=2.100e-04  val loss=2.152e-04
# [upd 40000/100000] train loss=2.016e-04  val loss=1.848e-04
# [upd 45000/100000] train loss=1.350e-04  val loss=1.502e-04
# [upd 50000/100000] train loss=1.375e-04  val loss=1.263e-04
# [upd 55000/100000] train loss=1.160e-04  val loss=1.148e-04
# [upd 60000/100000] train loss=8.178e-05  val loss=1.070e-04
# [upd 65000/100000] train loss=1.153e-04  val loss=9.223e-05
# [upd 70000/100000] train loss=1.028e-04  val loss=1.261e-04
# [upd 75000/100000] train loss=6.828e-05  val loss=8.628e-05
# [upd 80000/100000] train loss=9.777e-05  val loss=1.291e-04
# [upd 85000/100000] train loss=1.978e-04  val loss=2.533e-04
# [upd 90000/100000] train loss=9.490e-05  val loss=7.581e-05
# [upd 95000/100000] train loss=1.463e-04  val loss=1.206e-04
# [upd 100000/100000] train loss=1.792e-04  val loss=9.307e-05
# Test set performance:
#    Price: MAE=4.400e-03, RMSE=4.921e-03, R²=0.9999
#  Delta_0: MAE=1.932e-03, RMSE=4.133e-03, R²=0.9996
#  Delta_1: MAE=2.547e-03, RMSE=5.803e-03, R²=0.9991
#  Delta_2: MAE=1.995e-03, RMSE=3.829e-03, R²=0.9996
#   Vega_0: MAE=3.029e-03, RMSE=5.470e-03, R²=0.9992
#   Vega_1: MAE=3.273e-03, RMSE=6.915e-03, R²=0.9985
#   Vega_2: MAE=3.396e-03, RMSE=6.344e-03, R²=0.9989
